# %% [markdown]
# # Get Locations From U.S. Inaugural Addresses

# %% [markdown]
# ### Install spaCy

# %%
# !pip install -U spacy

# %% [markdown]
# ### Import Libraries

# %% [markdown]
# We're going to import `spacy` and `displacy`, a special spaCy module for visualization.

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400

# %% [markdown]
# We're also going to import the `Counter` module for counting people, places, and things, and the `pandas` library for organizing and displaying data (we're also changing the pandas default max row and column width display setting).

# %% [markdown]
# ### Download Language Model

# %% [markdown]
# Next we need to download the English-language model (`en_core_web_sm`), which will be processing and making predictions about our texts. This is the model that was trained on the annotated "OntoNotes" corpus. You can download the `en_core_web_sm` model by running the cell below:

# %%
# !python -m spacy download en_core_web_sm

# %% [markdown]
# ### Load Language Model

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
import glob
from pathlib import Path

# %%
filenames = glob.glob('../texts/history/US_Inaugural_Addresses/*.txt')

# %%
places = []

for file in filenames:
    text = open(file, encoding='utf-8').read()
    # Get the year from the file name -- it's always the last 4 digits
    year = Path(file).stem[-4:]
    # Run spacy on each address
    document = nlp(text)
    
    for named_entity in document.ents:
        if named_entity.label_ == "GPE":
            # Append a dictionary to the empty list 
            places.append({
                            "Place": named_entity.text,
                            "Year": year,
                            "Address":  Path(file).stem
                        })

# Make DataFrame from list of dictionaries -- the dictionary keys become the column names
df = pd.DataFrame(places)

# %%
def add_decade(year):
    year = int(year)
    if year < 1800:
        return "1700s"
    elif year < 1900:
        return "1800s"
    elif year < 2000:
        return "1900s"
    else:
        return "2000s"

# %%
df['Decade'] = df['Year'].apply(add_decade)

decade_df = df.groupby(['Place', 'Decade'])['Address'].count().reset_index()
decade_df = decade_df.rename(columns={'Address': 'Count'})

# %%
decade_df
# Out:
#                                             Place Decade  Count
# 0                                     Afghanistan  2000s      1
# 1                                         America  1700s      5
# 2                                         America  1800s      2
# 3                                         America  1900s    135
# 4                                         America  2000s     63
# 5                                         Argonne  1900s      1
# 6                                       Arlington  2000s      1
# 7                                          Athens  1800s      2
# 8                                       Baltimore  1800s      1
# 9                                         Bolivar  1800s      1
# 10                                         Boston  1900s      1
# 11                                          Burma  1900s      1
# 12                                     California  1800s      1
# 13                                       Camillus  1800s      1
# 14                                          China  1900s      1
# 15                                     Cincinnati  1800s      1
# 16                                      Communism  1900s      1
# 17                                        Concord  2000s      1
# 18                                          Cong.  1900s      1
# 19                                           Cuba  1900s      5
# 20                                         Dakota  1800s      1
# 21                                        Detroit  2000s      2
# 22                                        Discord  1800s      1
# 23                                       District  1800s      1
# 24                                          Egypt  1800s      1
# 25                                        England  1800s      2
# 26                                        Florida  1800s      2
# 27                                         France  1800s      1
# 28                                         France  1900s      1
# 29                                        Germany  1900s      1
# 30                                     Gettysburg  2000s      1
# 31                                  Great Britain  1800s      4
# 32                                    Guadalcanal  1900s      1
# 33                                          Hague  1900s      1
# 34                                     Indo-China  1900s      1
# 35                                           Iowa  1900s      1
# 36                                           Iraq  2000s      1
# 37                                         Israel  1800s      1
# 38                                          Italy  1900s      1
# 39                                       Iwo Jima  1900s      1
# 40                                        Jericho  2000s      1
# 41                                         Kansas  1800s      1
# 42                                          Korea  1900s      2
# 43                                        Liberty  1900s      1
# 44                                      Louisiana  1800s      3
# 45                                      Louisiana  1900s      1
# 46                                     Melancholy  1800s      1
# 47                                         Mexico  1800s      1
# 48                                    Mississippi  1800s      2
# 49                                       Missouri  1800s      1
# 50                                        Montana  1800s      1
# 51                                     Monticello  1800s      1
