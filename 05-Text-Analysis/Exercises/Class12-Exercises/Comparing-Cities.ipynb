# %% [markdown]
# # Word Shift Graphs — Comparing Cities

# %% [markdown]
# In this notebook, we will be comparing how people talk about Seattle vs. other cities — Portland, Chicago, LA, or Beijing — on Reddit. To do so, we will be using the `Shifterator` package, and we will be making word shift graphs.
#
# What we need to make word shift graphs with `Shifterator` is **two dictionaries for our two corpora** — dictionaries that have keys as words and values as how many times the words show up in the corpora. To make these dictionaries, we will go over how to use `Counter()` and how to transform Pandas DataFrame columns into dictionaries of word counts.

# %% [markdown]
# ## Update a Counter

# %%
from collections import Counter

# %%
fruits = ["apple", "apple", "banana", "kiwi", 'kiwi', "kiwi", 'banana']

# %% [markdown]
# By using Counter, we can count items in a collection, such as a list or dictionary, and return a dictionary of values and counts.

# %%
Counter(fruits)
# Out:
# Counter({'apple': 2, 'banana': 2, 'kiwi': 3})

# %% [markdown]
# We can also add items to a Counter with the `update()` method.

# %%
# Make an empty counter
fruit_counter = Counter()

# %%
# Add to it!
fruit_counter.update(fruits)

# %%
fruit_counter
# Out:
# Counter({'apple': 2, 'banana': 2, 'kiwi': 3})

# %% [markdown]
# We can also add a couple of oranges and a banana to our counter.

# %%
fruit_counter.update(['orange', 'orange', 'banana'])

# %%
fruit_counter
# Out:
# Counter({'apple': 2, 'banana': 3, 'kiwi': 3, 'orange': 2})

# %%
fruit_counter.most_common(2)
# Out:
# [('banana', 3), ('kiwi', 3)]

# %% [markdown]
# ## Make a Word Tokenizer

# %% [markdown]
# Make sure to run all of these cells and create these variables. If you're unsure, check your Variable Inspector.

# %%
from collections import Counter
import re

# %%
stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers',
 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves',
 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are',
 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does',
 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into',
 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here',
 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so',
 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 've', 'll', 'amp']

# %% [markdown]
# Complete the code below to create a function that tokenizes any text and returns a list of words.

# %%
def tokenize_words(text):
    lowercase_text = text.lower()
    split_words = re.split("\W+", lowercase_text)
    # Your code here
    return meaningful_words

# %%
tokenize_words("I love Seattle!!!")
# Out:
# ['love', 'seattle', '']

# %% [markdown]
# ## Seattle vs. Portland

# %%
import pandas as pd
pd.options.display.max_colwidth = 400

# %%
seattle_df = pd.read_csv('../reddit-data/Seattle-Reddit-Submissions-1k.csv', parse_dates=['date'])

# %% [markdown]
# Examine 10 random posts

# %%
# Your code here

# %%
pdx_df = pd.read_csv('../reddit-data/Portland-Reddit-Submissions-1k.csv', parse_dates=['date'])

# %% [markdown]
# Examine 10 random posts

# %%
# Your code here

# %% [markdown]
# ## Transform a Series Into a List

# %% [markdown]
# We can transform a column into a list with `.to_list()`

# %%
seattle_df['title'].to_list()

# %%
seattle_posts = seattle_df['title'].to_list()

# %%
pdx_posts = pdx_df['title'].to_list()

# %% [markdown]
# Let's loop through `seattle_posts`, tokenize each post, and print the list of tokenized words.

# %%
# Your code here
    tokenize_words(text)
# Out:
# ['seattle', 'votes', 'decriminalize', 'psilocybin', 'similar', 'substances']
# ['diamantenhände', 'seattle', 'german', 'market', 'open', '']
# ['anyone', 'else', 'enjoy', 'comparing', 'real', 'seattle', 'game', 'pioneer', 'place', '']
# ['ace', 'hardware', 'lake', 'city', 'seattle', 'enforces', 'mask', 'policy']
# ['diamantenhände', 'seattle', 'german', 'market', 'open', '']
# ['fight', 'mask', 'mandate', 'seattle', 'ace', 'hardware', '']
# ['ace', 'hardware', 'employee', 'seattle', 'wa', 'tries', 'enforce', 'mask', 'mandate', 'bat']
# ['', 'arnold', 'seattle', 'seahawks', 'jamal', 'adams', 'expected', 'participate', 'mandatory', 'minicamp', 'looks', 'sign', 'contract', 'extension']
# ['diamantenhände', 'seattle', 'german', 'market', 'open', '']
# ['eagle', 'taking', 'walk', 'rain', 'low', 'tide', 'west', 'seattle', '']
# ['new', '315', 'ship', 'shore', 'cranes', 'inbound', 'seattle', 'yesterday', 'aboard', 'zhen', 'hua', '36', 'cranes', 'welded', 'deck', 'ship', 'former', 'tanker', '50', 'ballast', 'tanks', 'water']
# ['dicks', 'burgers', 'seattle', 'offering', 'livable', 'wage', 'great', 'benefits', 'affordable', 'food', '']
# ['truck', 'wheels', 'stolen', 'seattle', 'stranger', 'offers', 'spares', 'free']
# ['diamantenhände', 'seattle', 'german', 'market', 'open', '']
# ['first', 'tattoo', 'done', 'mia', 'ink', 'tattoo', 'seattle', 'wa', '']
# ['seattle', 'washington', 'overpass', 'vibes', 'oc', '3968x4960', '']
# ['', 'kleiman', 'rift', 'russell', 'wilson', 'seahawks', 'happening', 'wilson', 'believes', 'top', '5', 'qb', 'time', 'also', 'believes', 'isn', 'currently', 'even', 'viewed', 'top', '10', 'qb', 'time', 'thinks', 'seattle', 'holding', 'back', 'certain', 'decisions', 'personnel', 'scheme', '']
# ['focus', 'states', '250', 'bills', 'restrict', 'voting', 'rights', '70', 'bills', 'restrict', 'transgender', 'rights', 'first', 'two', 'months', '2021']
# ['seattle', 'boeing', 'factory', 'disguised', 'fake', 'neighborhood', 'wwii', 'ground', 'burlap', 'canvas', 'chicken', 'wire', 'lawns', 'trees', 'spun', 'glass', 'chicken', 'feathers', 'buildings', '4ft', 'tall', '']
# ['6pm', 'seattle', 'sunsets', 'coming', 'soon']
# ['neon', 'snow', 'seattle']
# ['partner', 'using', 'miscarriages', 'control']
# ['seattle', 'police', 'bellevue', 'law', 'enforcement', 'immediately', 'stop', 'arresting', 'people', 'drug', 'possession']
# ['eagle', 'rescued', 'west', 'seattle']
# ['thief', 'stole', '15k', 'stuff', 'storage', 'unit', 'secured', 'garage', 'apartment', 'complex', '']
# ['addition', 'wealthy', 'switzerland', 'seattle', 'pool', 'boats', 'poor', 'pool', 'boats', 'wisconsin', 'picnic', 'table', 'boats', '']
# ['addition', 'wealthy', 'switzerland', 'seattle', 'us', 'poors', 'also', 'pool', 'boats', '']
# ['seattle', 'times', 'coming', 'hard', 'news', 'dick', '']
# ['addition', 'switzerland', 'seattle', 'latvia', 'also', 'floating', 'hottubs', 'boats', 'enjoy', '']
# ['addition', 'switzerland', 'seattle', 'also', 'hottub', 'boats', 'enjoy', 'lake', 'union', '']
# ['', 'greenberg', 'chicago', 'bears', 'really', 'persistent', 'reciprocating', 'interest', 'trading', 'seattle', 'seahawks', 'quarterback', 'russell', 'wilson', '']
# ['kraken', 'joining', 'current', 'seattle', 'sports', 'scene', '']
# ['', 'ctb', 'gruden', 'sea', 'drafting', 'russ', '2012', 'like', 'pick', 'm', 'jealous', 'seattle', 'wish', 'could', 'coach', 'kid', '']
# ['adam', 'schefter', 'twitter', 'wilson', 'told', 'seahawks', 'wants', 'play', 'seattle', 'trade', 'considered', 'teams', 'would', 'go', 'cowboys', 'saints', 'raiders', 'bears', '']
# ['', 'schefter', 'seahawks', 'qb', 'russell', 'wilson', 'demanded', 'trade', 'agent', 'mark', 'rodgers', 'told', 'espn', 'wilson', 'told', 'seahawks', 'wants', 'play', 'seattle', 'trade', 'considered', 'teams', 'would', 'go', 'cowboys', 'saints', 'raiders', 'bears', '']
# ['', 'kyed', 'seattle', 'going', 'issues', 'nine', 'years', 'wilson', 'career', 'makes', 'brady', 'belichick', '20', 'year', 'marriage', 'much', 'remarkable', '']
# ['', 'washington', 'urgent', 'open', 'carry', 'ban', 'likely', 'voted', 'senate', 'tomorrow', 'contact', 'senators', '']
# ['seattle', 'clear', 'morning', 'pentax645n', '75mm', 'f', '2', '8', 'portra400', '']
# ['', 'nightengale', 'seattle', 'mariners', 'prospect', 'jarred', 'kelenic', 'says', 'team', 'punishing', 'refusing', 'sign', 'contract', 'extension']
# ['fallout', 'game', 'set', 'pacific', 'northwest', 'would', 'offer', 'terrain', 'variety', 'series', 'overflowing', 'radioactive', 'desert']
# ['amazon', 'terrible', 'disgusting', 'overrated', 'way', 'large', 'company', 'waste', 'produces', 'one', 'biggest', 'problems', '']
# ['seattle', 'proud', 'boys', 'leader', 'threatened', 'war', 'ahead', 'capitol', 'riot', 'arrested']
# ['charge', 'solar', 'powered', 'watch', 'using', 'sun', 'therapy', 'lamp', 'live', 'seattle', '']
# ['morning', 'seattle']
# ['first', 'post', 'ever', 'reddit', 'wall', 'seattle', 'wa']
# ['', 'update', 'oh', 'gosh', 'guys', 'scooter', 'found', 'special', 'shout', 'u', 'nihilonym', 'connecting', 'op', 'neighborhood', 'app', 'lemon', 'back', 'home', 'belongs', 'nearly', 'damaged', 'thought', 'either', 'almost', '2', 'miles', 'stolen', 'thanks', 'r', 'seattle', '']
# ['lockdown', 'kickstarted', 'love', 'reading', 'back', 'may', 'created', 'nice', 'reading', 'corner', 'best', 'enjoy', 'new', 'hobbies', 'reading', 'collecting', 'books', 'much', 'better', 'mostly', 'empty', 'corner', 'used', 'seattle', 'wa', '']
# ['three', 'cheers', 'bokhee', 'blessed', 'person', 'seattle', 'grace', 'mercy', 'death', 'living', 'life', 'drama', 'free', 'since', '2005', '']
# ['snapped', 'shot', 'seattle', 'public', 'library', 'day']
# ['', 'curtis', 'rogers', 'greg', 'olsen', 'told', 'colin', 'cowherd', 'today', 'liked', 'time', 'seattle', 'buyer', 'remorse', 'joining', 'buffalo', 'know', 'else', 'buyer', 'remorse', 'greg', 'seahawks', 'paid', '7m', 'barely', 'production']
# ['seattle', '1951']
# ['seattle', '1951']
# ['atrium', 'full', 'natural', 'light', 'refurbished', 'renovated', 'mid', 'century', 'modern', 'residence', 'asian', 'inspired', 'aesthetics', 'seward', 'park', 'seattle', 'washington', 'originally', 'designed', 'architect', 'paul', 'kirk', 'finished', '1953', 'renovated', 'olson', 'kundig', '2015', '']
# ['every', 'mlb', 'team', 'moved', 'least', 'populated', 'town', 'respective', 'state', 'well', 'research', 'renamed', 'every', 'team', 'accordingly']
# ['', 'oc', 'turns', 'flying', 'seattle', 'phoenix', 'takes', 'directly', 'grand', 'canyon', '4032x2268', '']
# ['photograph', 'brave', 'seattle', 'ironworker', '1980', '']
# ['man', 'enjoying', 'beer', 'local', 'bar', 'seattle', 'wa', 'approximately', '1950']
# ['bookstore', 'closed', 'sign', 'seattle']
# ['dad', 'airline', 'pilot', '33', 'years', 'depart', 'san', 'diego', 'seattle', 'hours', 'final', 'flight', 'career', 'boarded', 'plane', 'headed', 'san', 'diego', 'surprise', 'join', 'last', 'leg', 'journey', 'retirement', '']
# ['federal', 'cops', 'already', 'seattle', 'mayor', 'pissed']
# ['love', 'game', 'hockey', 'city', 'seattle', 'came', 'together', 'today', '']
# ['newest', 'team', 'nhl', 'seattle', 'kraken', 'revealed', 'logos', 'anchor', 'space', 'needle', '']
# ['report', '1500', 'increase', 'seattle', 'homeowners', 'moving', 'area', 'compared', 'last', 'year', '']
# ['seattle', 'kraken', 'getting', 'ready', 'expansion', 'draft', 'twitter', '']
# ['seattle', 'nhl', 'team', 'named', 'kraken']
# ['seattle', 'announces', 'seattle', 'kraken', 'nhl', 'team']
# ['', 'seattle', 'welcome', 'seattle', 'kraken']
# ['', 'nhl', 'seattle', '32nd', 'franchise', 'comes', 'life', '']
# ['entire', 'government', 'body', 'infiltrated', 'sickos']
# ['seattle', 'portland', 'whatever', 'shithole']
# ['edith', 'macefield', 'house', 'ballard', 'neighborhood', 'seattle', 'washington', '1960', '2019', 'inspired', 'movie', '']
# ['mother', 'chop', 'shooting', 'victim', 'files', 'wrongful', 'death', 'claim', 'seattle']
# ['seattle', 'ban', 'crowd', 'control', 'weapons', 'violated', 'consent', 'decree', 'says', 'doj']
# ['', 'lost', 'sauce', 'authoritarian', 'test', 'run', 'portland']
# ['protesters', 'seattle', 'peacefully', 'looting', 'amazon', 'go']
# ['love', 'flying', 'seattle', 'never', 'gets', 'old']
# ['first', 'seattle', 'portland', '14', 'years', 'old', 'd', 'say', 'went', 'pretty', 'well', '']
# ['first', 'fill', 'picking', 'seattle']
# ['black', 'police', 'chief', 'explains', 'seattle', 'councilwoman', 'fire', 'white', 'officers']
# ['british', 'ambassador', 'us', 'launched', 'official', 'complaint', 'arrest', 'independent', 'journalist', 'covering', 'protests', 'seattle', 'journalist', 'andrew', 'buncombe', 'shackled', 'assaulted', 'detained', 'six', 'hours', 'accused', 'failing', 'disperse', 'seattle', '']
# ['', 'seattle', 're', 'putting', 'lawlessness', '2', 'antifa', 'women', 'charged', 'terrorism', '']
# ['fox', 'news', 'publishes', 'digitally', 'altered', 'misleading', 'images', 'seattle', 'demonstrations']
# ['fox', 'news', 'removes', 'digitally', 'altered', 'image', 'seattle', 'protests']
# ['fox', 'news', 'doctored', 'photos', 'seattle', 'protest', 'zone', 'report']
# ['fox', 'news', 'publishes', 'digitally', 'altered', 'misleading', 'images', 'seattle', 'demonstrations']
# ['seattle', 'need', 'flood', 'internet', 'videos', 'peaceful', 'reality', '']
# ['seattle', 'coronavirus', 'survivor', 'gets', '1', '1', 'million', '181', 'page', 'hospital', 'bill', 'italian', 'imagine', 'country', 'free', 'healthcare', 'wonder', 'could', 'someone', 'recover', '']
# ['seattle', 'coronavirus', 'survivor', 'gets', '1', '1', 'million', '181', 'page', 'hospital', 'bill', 'italian', 'imagine', 'country', 'free', 'healthcare', 'wonder', 'could', 'someone', 'recover', '']
# ['seattle', 'silent', 'march', 'today', 'rain', 'move', 'together', 'silence', '']
# ['aclu', 'showed', 'federal', 'judge', 'footage', 'violence', 'police', 'used', 'peaceful', 'protesters', 'judge', 'richard', 'jones', 'issued', 'temp', 'restraining', 'order', 'preventing', 'seattle', 'police', 'department', 'using', 'pepper', 'spray', 'tear', 'gas', 'chemical', 'weapons', 'force', 'peaceful', 'protesters', '']
# ['judge', 'bars', 'seattle', 'police', 'using', 'tear', 'gas', 'force', 'nonviolent', 'protesters']
# ['hyundai', 'veloster', 'n', 'performance', '13', '000', 'mile', 'review', 'update']
# ['finished', 'mural', 'pine', 'st', 'seattle', '']
# ['last', 'us', 'part', 'ii', 'review', 'thread']
# ['right', 'wing', 'media', 'says', 'antifa', 'militants', 'seized', 'part', 'seattle', 'local', 'authorities', 'say', 'otherwise']
# ['seattle', 'mayor', 'says', 'would', 'illegal', 'trump', 'sent', 'military', 'clear', 'protest', 'encampment']
# ['matt', 'gaetz', 'promoted', 'conspiracy', 'theory', 'antifa', 'seattle', 'describing', 'peaceful', 'protests', 'fictitious', 'takeover', 'city']
# ['virgin', 'seattle', 'vs', 'chad', 'sealand']
# ['chaz', 'mistake']
# ['hey', 'heard', 'tearing', 'statues', 'lenin', 'statue', 'seattle', 'next', '']
# ['trump', 'threatens', 'invade', 'seattle', 'mayor', 'tells', 'go', 'back', 'bunker', '']
# ['', 'brandon', 'bostick', 'may', 'bitter', 'sweet', 'month', 'personally', 'diagnosed', 'anxiety', 'depression', 'seattle', 'game', 'turned', '31', 'graduated', 'college', 'completed', '2', 'dreams', '5years', 'nfl', 'college', 'degree', 'god', 'great', 'part', 'story', 'mentalhealthmatters']
# ['seattle', 'mayor', 'responds', 'trump', 'go', 'back', 'bunker', '']
# ['seattle', 'mayor', 'tells', 'trump', 'go', 'back', 'bunker', 'criticizes', 'handling', 'protests']
# ['seattle', 'autonomous', 'zone', 'entering', 'free', 'cap', 'hill', '']
# ['follow', 'seattle', 'shooter', 'nikolas', 'fernandez', 'new', 'footage', 'shows', 'pedestrians', 'began', 'chasing', 'car', 'turned', 'onto', 'street', 'leading', 'towards', 'protestors', 'fernandez', 'charged', 'one', 'count', 'first', 'degree', 'assault', '']
# ['trump', 'seattle', 'm', 'really', 'really', 'gonna', 'm', 'going', 'send', 'army', 'take', 'back', 'seattle', 'seattle', 'trump', 'yawn', 'go', 'back', 'bunker', '']
# ['seattle', 'mayor', 'tells', 'trump', 'go', 'back', 'bunker', 'president', 'tells', 'take', 'back', 'city', 'protesters']
# ['trump', 'threatened', 'invade', 'seattle', 'mayor', 'governor', 'rejected', 'offer', 'light', 'mockery', '']
# ['', 'radical', 'left', 'governor', 'jayinslee', 'mayor', 'seattle', 'taunted', 'played', 'level', 'great', 'country', 'never', 'seen', 'take', 'back', 'city', 'game', 'ugly', 'anarchists', 'must', 'stooped', 'immediately', 'move', 'fast', 'trump', 'twitter']
# ['capitol', 'hill', 'autonomous', 'zone', 'educational', 'movie', 'night', 'seattle', 'without', 'militarized', 'police', 'riotous', 'looters', 'watching', 'documentaries', 'fuck', 'spd', 'photo', 'credit', 'close', 'friend', '']
# ['seattle', 'anarchists', 'try', 'start', 'autonomous', 'commune', 'within', '2', 'days', 'taken', 'heavily', 'armed', 'warlord', 'crew', 'turns', 'mad', 'max', 'dystopia']
# ['70', 'year', 'old', 'man', 'getting', 'boot', 'metallica', 'moshpit', '8', '9', '17', 'seattle', 'wa', '']
# ['ran', 'franchise', 'hockey', 'manager', 'every', 'team', 'without', 'cup', 'won', 'least', 'us', 'won', 'live', 'see', 'last', 'team', 'win', '']
# ['seattle', 'autonomous', 'zone']
# ['seattle', 'autonomous', 'zone', 'one', 'antifa', 'organizers', 'seattle', '18', 'year', 'old', 'lesbian', 'anarchist', 'wants', 'abolish', 'whiteness', 'capitalism', 'civilization', 'begged', 'vegan', 'meats', 'soy', 'homeless', 'people', 'invited', 'took', 'food', '']
# ['hey', 'heard', 'tearing', 'statues', 'lenin', 'statue', 'seattle', 'next', '']
# ['hmmm', 'looks', 'like', 'communism', 'isn', 'working', 'well', 'newly', 'established', 'antifa', 'autonomous', 'zone', 'seattle']
# ['like', 'seattle']
# ['seattle', 'residents', 'taken', 'city', 'hall', '']
# ['grandmother', 'turned', '102', 'today', 'care', 'facility', 'seattle', 'couldn', 'visit', 'nurses', 'helped', 'us', 'zoom', 'amazing', '']
# ['woman', 'struck', 'flashbang', 'seattle']
# ['saw', 'someone', 'headass', 'call', 'folks', 'capitol', 'hill', 'autonomous', 'zone', 'larpers']
# ['black', 'lives', 'matter', 'sues', 'violent', 'seattle', 'police', 'tactics']
# ['o7', 'seattle']
# ['zone', 'control', 'map', 'seattle', 'battlespace', 'free', 'seattle', 'army', 'fsa', 'controls', 'several', 'blocks', 'pushing', 'back', 'seattle', 'authority', 'agents', 'saa', 'unclear', 'erdogan', 'react', '']
# ['seattle', 'pd', 'hit', '21', 'year', 'old', 'female', 'directly', 'chest', 'stun', 'grenade', '']
# ['woman', 'keeps', 'seattle', 'protests', 'blazing', 'hot', 'handing', 'free', 'cannabis']
# ['online', 'voting', 'system', 'made', 'seattle', 'based', 'democracy', 'live', 'hacked', 'alter', 'votes', 'without', 'detection', 'according', 'report', 'mit', 'university', 'michigan']
# ['seattle', 'shooter', 'brothers', 'spd', 'cop', 'info', 'inside', '']
# ['camera', 'crushed', 'police', 'protest', 'cops', 'formatted', 'sd', 'card', 'dead', 'hard', 'drive', 'w', 'footage', 'cop', 'engaging', 'misconduct', 'help', 'get', 'photos', 'back']
# ['seattle', 'pd', 'hit', '21', 'year', 'old', 'female', 'directly', 'chest', 'stun', 'grenade', 'volunteer', 'medics', 'protesters', 'rushed', 'aid', 'carried', 'away', 'unresponsive', 'pulse', 'revived', 'remains', 'critical', 'condition', '']
# ['half', 'canadian', 'population', 'lives', 'south', 'seattle']
# ['camera', 'crushed', 'police', 'protest', 'cops', 'formatted', 'sd', 'card', 'dead', 'hard', 'drive', 'w', 'footage', 'cop', 'engaging', 'misconduct', 'help', 'get', 'photos', 'back']
# ['seattle', 'pd', 'shoot', 'woman', 'chest', 'unknown', 'canister', 'lost', 'pulse', 'rushed', 'hospital', 'condition', 'unknown']
# ['found', 'near', 'volunteer', 'park', 'seattle', '']
# ['night', '2', 'seattle', 'pd', 'banned', 'using', 'tear', 'gas', '30', 'days']
# ['1', 'hour', 'ago', 'seattle', '11th', 'pine', 'protesters', 'peacefully', 'inching', 'forward', 'public', 'streets', 'cops', 'didn', 'like', 'claimed', 'someone', 'threw', 'bottle', 'one', 'proceeded', 'use', 'flash', 'bangs', 'cs', 'gas', '2', 'days', 'cs', 'gas', 'ban', '']
# ['shooting', 'capitol', 'hill', 'seattle', 'angles', '']
# ['community', 'rallies', 'cleanup', 'downtown', 'seattle', 'violent', 'protests', 'looting']
# ['fictoria', 'bn', 'travelers', 'trash', 'violating', 'stay', 'home', 'covid', 'orders']
# ['wwii', 'vet', 'seattle', 'mariners', 'game', 'getting', 'excited']
# ['shooting', 'start', 'seattle', 'great', 'wheel', 'learning', 'new', 'editing', 'fun', 'staying', 'home', '']
# ['representing', 'seattle', 'university']
# ['mt', 'rainier', 'seattle', 'washington', 'usa']
# ['', 'rapoport', 'former', 'seahawks', 'qb', 'tarvaris', 'jackson', 'died', 'last', 'night', 'car', 'accident', 'alabama', 'spokesperson', 'employer', 'tennessee', 'state', 'tells', 'jackson', '36', 'tsu', 'qb', 'coach', 'along', 'seattle', 'also', 'played', 'vikings', 'bills', '']
# ['', 'ian', 'rapoport', 'former', 'seahawks', 'qb', 'tarvaris', 'jackson', 'died', 'last', 'night', 'car', 'accident', 'alabama', 'spokesperson', 'employer', 'tennessee', 'state', 'tells', 'jackson', '36', 'tsu', 'qb', 'coach', 'along', 'seattle', 'also', 'played', 'vikings', 'bills', '']
# ['kevin', 'garnett', 'recently', 'revealed', 'deep', 'affinity', 'seattle', 'would', 'love', 'able', 'go', 'buy', 'seattle', 'supersonics', 'reactivate', 'pacific', 'northwest', 'seattle', 'huge', 'league', '']
# ['', 'mcmanus', 'eagles', 'currently', '1', '5', 'point', 'underdogs', 'home', 'seattle', 'holds', 'philly', 'would', 'underdog', '6th', 'straight', 'playoff', 'game', 'doug', 'pederson', '4', '1', 'playoffs', 'underdog', 'coach', 'since', '2016', '1', 'playoff', 'win', '']
# ['49ers', 'fullback', 'kyle', 'juszczyk', 'juice', 'expected', 'return', 'line', 'week', 'good', 'news', 'tevin', 'coleman', 'matt', 'breida', 'owners', '']
# ['foggy', 'seattle', 'morning', 'landing']
# ['seattle', 'announce', 'team', 'name', 'star', 'game']
# ['', 'yates', 'russell', 'wilson', 'far', '2019', '200', '293', '68', '3', '2', '505', '22', 'td', '1', 'int', 'seattle', '7', '2', 'clear', 'cut', 'mvp', 'front', 'runner', '']
# ['want', 'say', 'thanks', 'random', 'seattle', 'man', 'also', 'thank', 'growth', 'gone']
# ['toronto', 'fc', 'advances', 'mls', 'cup', '2019']
# ['mls', 'cup', 'final', 'contested', 'seattle', 'sounders', 'toronto', 'fc', 'third', 'time', 'last', 'four', 'years']
# ['tom', 'brady', 'played', 'devin', 'bush', 'jr', 'christian', 'mccaffrey', 'also', 'played', 'fathers', '']
# ['left', 'friend', 'jeff', 'seattle', '1980']
# ['full', 'moon', 'setting', 'olympic', 'mountains', 'sunrise', 'seen', 'seattle', 'oc', '1822x1357', '']
# ['sr', '71', 'blackbird', 'museum', 'flight', 'seattle', '']
# ['last', 'day', 'seattle', 'went', 'colombia', 'tower', 'sunset', 'disappoint', '']
# ['somali', 'refugee', 'became', 'director', 'seattle', 'clinic', 'cared', 'child']
# ['office', 'dwight', 'says', 'tips', 'urologist', 'pulverize', 'kidneys', 'stones', 'beets', 'known', 'cause', 'kidney', 'stones', '']
# ['tifu', 'playing', 'music', 'sex', 'dungeon']
# ['fall', 'looks', 'pretty', 'darn', 'good', 'tree', 'seattle', 'oc', '801x1200', 'ross_schram']
# ['', 'breer', 'bennett', 'dealt', '2018', 'seattle', 'philly', '7', 'wr', 'marcus', 'johnson', '5', 'bennett', 'dealt', '2019', 'philly', 'ne', '7', '5', 'bennett', 'dealt', 'later', '2019', 'ne', 'dallas', 'conditional', '6', '7', 'sometimes', 'everyone', 'else', 'isn', 'problem', '']
# ['6', '5s', 'shutter', 'highway', '99', 'seattle']
# ['seattle', 'mariners', 'fans', 'unsure', 'teams', 'still', 'playing', 'baseball', 'october', 'babylon', 'bee']
# ['', 'babylon', 'bee', 'seattle', 'mariners', 'fans', 'unsure', 'teams', 'still', 'playing', 'baseball', 'october']
# ['hey', 'seattle', '']
# ['seattle', 'going', 'completion', '']
# ['seattle', 'decides', 'replace', 'public', 'school', 'math', 'classes', 'new', 'humanized', 'math', 'classes', 'designed', 'teach', 'children', 'hate', 'west', 'white', 'people']
# ['seattle', 'vs', 'tacoma', 'wa', 'seattle', 'explode', 'growth', 'tacoma', 'stagnated', '']
# ['threats', 'trump', 'family', 'media', 'targets', 'get', 'seattle', 'man', '5', 'years', 'behind', 'bars']
# ['moved', 'seattle', 'wa', 'love', '']
# ['fall', 'seattle', 'one', 'best', 'ever', 'shot', 'today', 'north', 'bend', '']
# ['careful', 'taking', 'qa', 'role', 'really', 'want', 'swe', 'work']
# ['seattle', 'sunset', 'olympic', 'national', 'park', 'backdrop', '']
# ['eddie', 'vedder', 'hanging', 'rafters', 'drop', 'park', 'concert', 'seattle', 'september', '20', '1992', 'photo', 'lance', 'mercer', '1080', 'x', '1601', '']
# ['castle', 'flames', 'done', 'chrome', 'ohm', 'tattoo', 'seattle', 'wa']
# ['people', 'think', 'seattle', 'like', 'starter', 'pack']
# ['', 'fillipponi', 'johnclaytonnfl', 'reporting', 'browns', 'dyfunction', 'sunday', 'lot', 'talk', 'freddie', 'kitchens', 'almost', 'fired', 'seattle', 'loss', '']
# ['little', 'reading', 'nook', 'pike', 'place', 'market', 'seattle', 'usa']
# ['', 'fann', 'bobby', 'wagner', 'seahawks', 'fans', 'react', 'earl', 'thomas', 'returning', 'seattle', 'appreciation', 'much', 'organization', 'legend', 'would', 'expect', 'well', 'received', 'wagner', 'said', 'plans', 'swapping', 'jerseys', 'thomas', '']
# ['washington', 'nationals', 'advancement', 'seattle', 'mariners', 'lone', 'current', 'mlb', 'team', 'never', 'appear', 'world', 'series']
# ['bremerton', 'seattle', 'commute', 'rush', 'hour']
# ['seattle', 'center']
# ['seattle', 'barely', 'squeezes', 'win', 'browns']
# ['took', 'amtrak', 'san', 'jose', 'seattle', 'day', 'pic', 'arrived', '']
# ['lil', 'goblin', 'finally', 'done', 'done', 'derek', 'noble', 'dark', 'age', 'seattle', 'wa', '']
# ['embracing', 'rain', 'moving', 'back', 'home', 'thomas', 'sinnamond', 'studio', 'nimbus', 'seattle']
# ['apparently', 'fastest', 'bus', 'existence', 'google', 'maps', 'seattle', 'kyrgyzstan', 'back', 'seattle', '47', 'minutes']
# ['movie', 'based', 'seattle', 'starter', 'pack']
# ['found', 'apparently', 'fastest', 'bus', 'existence', 'google', 'maps', 'seattle', 'kyrgyzstan', 'back', 'seattle', '47', 'minutes']
# ['seattle', 'rapid', 'access', 'tool']
# ['post', 'game', 'thread', 'los', 'angeles', 'rams', '3', '2', 'seattle', 'seahawks', '4', '1', '']
# ['sincerely', 'disturbed', 'transparently', 'many', 'members', 'associated', 'press', 'hoping', 'mass', 'murder', 'opening', 'weekend', 'joker', '']
# ['pinnacle', 'seattle', 'architecture', 'could', 'adorn', 'home', 'dozens', 'terra', 'cotta', 'walri', 'would', '']
# ['space', 'needle', 'seattle', 'clouds', 'looks', 'like', 'cloud', 'city', 'star', 'wars']
# ['seattle', 'journalists', 'made', 'documentary', 'man', 'choice', 'end', 'life', 'using', 'washington', 'death', 'dignity', 'law', 'ask', 'us', 'anything']
# ['giraffe', 'man', 'seattle', 'seattle', 'show', 'like']
# ['incredible', 'photo', 'king', 'felix', 'final', 'moments', 'seattle', 'mariners', 'via', 'alexiniguez', '']
# ['two', 'couples', 'didn', 'know', 'walking', 'pike', 'place', 'market', 'seattle', 'dogs', 'stopped', 'ran', 'toward', 'turns', 're', 'sisters', 'litter', 'russia', 'shared', 'plane', 'year', 'earlier', 'hadn', 'seen', 'since', 'regular', 'play', 'dates', '']
# ['indiana', 'jones', 'temple', 'doom', 'ready', 'brickcon', 'seattle', 'wa', 'next', 'week', '']
# ['week', 'bungie', '9', '26', '2019']
# ['two', 'couples', 'didn', 'know', 'walking', 'pike', 'place', 'market', 'seattle', 'dogs', 'stopped', 'ran', 'toward', 'turns', 're', 'sisters', 'litter', 'russia', 'shared', 'plane', 'year', 'earlier', 'hadn', 'seen', 'since', 'regular', 'play', 'dates', '']
# ['millionaire', 'ceo', 'dan', 'price', 'raises', 'minimum', 'salary', 'idaho', 'employees', '70', '000', 'four', 'years', 'seattle', 'workers', 'slashing', '1', 'million', 'pay', 'day']
# ['seattle', 'hires', 'cammi', 'granato', 'nhl', 'first', 'female', 'pro', 'scout']
# ['downtown', 'seattle', '']
# ['long', 'toxic', 'relationship', 'm', 'finally', 'smiling', 'got', 'apartment', 'seattle', 'took', 'teaching', 'job', 'servicing', 'community', 'feels', 'good', 'happy', 'optimistic', 'life', 'cheers', '']
# ['gentle', 'seattle']
# ['saw', 'people', 'owl', 'concept', 'teams', 'mine', 'meet', 'seattle', 'thunder']
# ['pokémon', 'going', 'hard', 'times']
# ['hunger', 'games', 'seattle', 'library', 'checkouts', 'time', 'oc', '']
# ['', 'adelson', 'teddy', 'bridgewater', 'wins', 'game', 'saints', 'seattle', 'three', 'years', 'gruesome', 'knee', 'injury', 'nearly', 'ended', 'career', '']
# ['ulpt', 'want', 'expensive', 'drink', 'starbucks', 'cheap', 'order', 'cheap', 'drink', 'peach', 'juice', '']
# ['got', 'lot', 'hate', 'posting', 'r', 'pics', 'really', 'believe', 'movement', 'seattle', 'wa']
# ['seattle', 'seasons']
# ['ama', 'visited', '100', 'top', 'colleges', '360', 'full', 'campus', 'tour', 'videos', 'youtube', 'ama']
# ['seattle', 'post', 'rain']
# ['', 'young', 'people', 'correct', 'outraged', 'seattle', 'city', 'council', 'urges', 'public', 'schools', 'let', 'students', 'join', 'global', 'climate', 'strike', 'sept', '20']
# ['', 'young', 'people', 'correct', 'outraged', 'seattle', 'city', 'council', 'urges', 'public', 'schools', 'let', 'students', 'join', 'global', 'climate', 'strike']
# ['downpour', 'seattle', 'last', 'week', 'bonus', 'thunder', 'lightening', 'end', 'sorry', 'shaky', 'cam', 'pup', 'pulling', 'leash', 'enjoy', 'rain', '']
# ['live', 'austin', 'grew', 'seattle', 'clouds', 'look', 'like', 'rainier', '']
# ['inspired', 'orca', 'flag', 'design', 'seattle', 'took', 'stab', 'redesigning', 'bellevue', 'flag']
# ['federal', 'center', 'south', 'new', 'regional', 'headquarters', 'us', 'army', 'corps', 'engineers', 'seattle', 'wa', '3000', 'x', '2000', '']
# ['living', 'room', 'seattle', 'wa', '']
# ['seattle', 'meme']
# ['found', 'downtown', 'seattle', 'wa', 'today', '']
# ['', 'kollman', '2017', 'new', 'england', '2017', 'seattle', '2018', 'philadelphia', '2019', 'new', 'orleans', 'deshaun', 'watson', 'team', 'lead', 'minute', 'left', 'fourth', 'quarter', 'four', 'games', 'houston', 'lost', 'four', 'games', 'prevent', 'defense', 'coaches', 'deserve', 'deshaun', '']
# ['amazon', 'employees', 'walk', 'climate', 'change', 'inaction', 'planned', 'event', 'mark', 'first', 'time', 'amazon', '25', 'year', 'history', 'workers', 'company', 'seattle', 'headquarters', 'participated', 'strike', '']
# ['awesome', 'borderlands', 'art', 'colin', 'seattle']
# ['lightning', 'knocking', 'power', 'rolling', 'back', 'seattle']
# ['get', 'many', 'thunderstorms', 'seattle', 'thought', 'share', 'short', 'video', 'took', 'tonight', '']
# ['seattle', 'wa']
# ['seattle', 'kids', 'without', 'measles', 'vaccine', 'paperwork', 'excluded', 'school']
# ['seattle', 'mariners', 'eliminated', 'postseason', 'contention']
# ['hi', 'm', 'neighbour', 'north', 'seemed', 'lost', 'one', 'crows', 'spotted', 'seattle', 'please', 'contact', 'joke', '']
# ['xephos', 'magical', 'rapier', 'wrote', 'stories', 'kid', 'heidi', 'scheck', 'seattle', '']
# ['photo', 'took', 'seattle', 'ended', 'looking', 'like', 'painting']
# ['every', 'like', 'remind', 'moved', 'north', 'dakota', 'seattle', '']
# ['walk', 'dog', 'leash', 'fuck', '']
# ['help', 'find', 'mom', 'daughter', 'give', 'awesome', 'picture', 'last', 'nights', 'blink', '182', 'show', 'seattle', '']
# ['absolutely', 'loving', 'custom', 'sodas', 'given', 'eso', 'event', 'seattle', 'last', 'night', '']
# ['', 'schefter', 'capper', 'saturday', 'trade', 'houston', 'paid', 'jadeveon', 'clowney', '7', 'million', 'signing', 'bonus', 'seattle', 'paying', 'remaining', '8', 'million', 'salary', 'per', 'source', 'seattle', 'also', 'promised', 'tag', 'clowney', 'season', 'per', 'source']
# ['seattle', 'right']
# ['', 'fann', 'seattle', 'going', 'cut', 'mingo', '1', 'p', 'm', 'pt', 'today', 'using', 'chip', 'get', 'star', 'pass', 'rusher', 'larceny', '']
# ['visited', 'pax', 'west', 'booth', 'today', 'seattle', 'hype', 'real', '']
# ['typical', 'seattle', 'bus', 'lane']
# ['name', 'shame', 'zillow']
# ['seattle', 'dressed', 'baltimore']
# ['saw', 'incredible', 'sky', 'olympic', 'mountains', 'apartment', 'seattle', 'oc', '']
# ['sky', 'made', 'rainbow', 'tonight', 'seattle', 'wa']
# ['first', 'regular', 'season', 'matchup', 'michael', 'jordan', 'refused', 'shake', 'gary', 'payton', 'hand', 'said', 'loud', 'leave', 'expletive', 'rookie', 'game', 'mj', 'said', 'gp', 'real', 'expletive', 'right', 'welcome', 'nba', 'little', 'fella', '']
# ['seattle', 'public', 'library', 'denounces', 'publisher', 'new', 'e', 'book', 'policy']
# ['size', 'mt', 'rainier', 'always', 'captivates', 'seattle', 'scale', '']
# ['elizabeth', 'warren', 'tells', 'seattle', 'center', 'crowd', '15', '000', 'dumping', 'trump', 'enough', '']
# ['elizabeth', 'warren', 'draws', 'record', 'crowd', '15', '000', 'seattle']
# ['spotted', 'rest', 'area', 'north', 'seattle']
# ['park', 'wrong', 'spot', 'prepared', 'leisurely', 'mc']
# ['seattle', 'patch', '13', 'earned', 'continuously', 'hearing', 'customer', 'assistance', 'needed', 'premium', 'liquor', 'aisle', 'entire', 'time', 'shop', 'groceries']
# ['last', '19', 'years', 'seattle', 'supersonics', 'won', 'playoff', 'games', 'new', 'york', 'knicks']
# ['obligatory', 'anti', 'bandwagon', 'post']
# ['full', 'moon', 'setting', 'sunrise', 'seen', 'seattle', 'oc', '1999x2000', '']
# ['want', 'share', 'story', 'pokemon', 'go', 'friend', 'recently', 'passed', 'away']
# ['tale', 'two', 'cities', 'bellevue', 'seattle']
# ['seattle', 'stands', 'hong', 'kong']
# ['fan', 'ejected', 'la', 'galaxy', 'stadium', 'banner', 'reading', 'anti', 'fascist', 'anti', 'racist', 'always', 'seattle', 'league', 'policy', 'according', 'club', 'league', 'officials', '']
# ['', 'house', 'woods', 'bedroom', 'seattle', '658x990', '']
# ['ym', 'ultimate', 'leaving', 'seattle']
# ['support', 'hong', 'kong', 'assemblies', 'us', 'canada', 'uk', 'france', 'belgium', 'germany', 'australia', 'nz', 'jp', 'tw', 'denmark', 'norway']
# ['neo', 'nazi', 'group', 'planning', 'holding', 'hate', 'camp', 'spokane', 'wa', 'month']
# ['seattle', 'natives', 'transplants', 'weekend']
# ['apollo', '11', 'command', 'module', 'worth', 'drive', 'seattle', '']
# ['saints', 'signed', 'waived', 're', 'signed', 'j', 'barrett', '25', 'times', 'last', 'year', 'cut', 'days', 'training', 'camp', 'seattle', 'seahawk']
# ['women', 'fed', 'violators', 'slowing', 'city', 'metro', 'tells', 'cars', 'get', 'fuck', 'bus', 'lane', 'downtown', 'seattle', 'wa', 'cheers', 'nearby', '']
# ['satanic', 'temple', 'seattle', 'lot', 'homeless', '']
# ['', 'never', 'jewish', 'leaders', 'protest', 'ice', 'seattle']
# ['never', 'change', 'seattle', 'never', 'change']
# ['grading', 'ever', 'team', 'offseason', 'seattle', 'supersonics', '2', '31', '']
# ['collectibles', 'cabinet', 'seattle', 'space', 'needle', '']
# ['peak', 'seattle', 'right']
# ['sunny', 'room', 'trees', 'seattle', 'wa', '']
# ['saved', 'newborn', 'life', 'last', 'summer', 'pizza', 'jacket', '']
# ['houston', 'astros', 'thrown', 'combined', 'hitter', 'seattle', 'mariners', '']
# ['blue', 'angels', 'seattle', 'seafair']
# ['found', 'free', 'water', 'dispenser', 'seattle']
# ['found', 'seattle', 'art', 'show']
# ['cultured', 'thinking', 'mans', 'haven', 'right', 'heart', 'seattle', 'exception', 'dads', 'old', 'chair', '']
# ['friend', 'mine', 're', 'designing', 'seattle', 'flag', 'go']
# ['annette', 'lake', 'outside', 'seattle', 'north', 'bend', 'washington', 'usa', '8ish', 'mike', 'round', 'trip', 'hike']
# ['maga', 'hat', 'wearers', 'get', 'egged', 'milkshaked', '3', 'times', 'giving', 'free', 'hugs', 'seattle', 'police', 'nothing', 'unbelievable']
# ['living', 'space', 'seattle', '']
# ['raining', 'seattle', 'oc', '']
# ['chris', 'ballew', 'artist', 'profile', '2017', 'former', 'frontman', 'seattle', 'rock', 'band', 'presidents', 'united', 'states', 'america', 'makes', 'kids', 'music', 'name', 'caspar', 'babypants', '00', '09', '40', '']
# ['dad', 'finally', 'reunited', 'dog', 'last', 'time', 'visited', 'home', 'live', 'la', 'dad', 'lives', 'seattle', 'facetimes', 'least', 'day', 'specifically', 'talk', 'dog', '']
# ['mri', 'revealed', 'bengals', 'wr', 'j', 'green', 'torn', 'ligaments', 'left', 'ankle', 'likely', 'sideline', 'six', 'eight', 'weeks', 'source', 'tells', 'espn', 'green', 'expected', 'ready', 'regular', 'season', 'opener', 'seattle', '']
# ['cozy', 'bedroom', 'seattle', 'wa', 'absolutely', 'love', 'windows', 'trees', '']
# ['meet', 'prep', 'seattle', 'brit', 'inbound', '']
# ['', 'greif', 'ballmer', 'lives', 'seattle', 'former', 'nba', 'city', 'said', 'clippers', 'home', 'remain', 'l', 're', 'moving', 'ballmer', 'said', 'wife', 'connie', 'neither', 'basketball', 'team', 'let', 'get', 'way', '']
# ['seattle', 'studio']
# ['', 'trashtag', 'seattle', 'picked', 'trash', 'discovery', 'park', 'weekend']
# ['crunched', 'numbers', 'whenever', 'justin', 'holiday', 'signs', 'pacers', 'able', 'make', 'proclamation', 'official', 'best', 'offseason', 'ever', '']
# ['beauty', 'heterochromia', 'found', 'café', 'seattle']
# ['seattle', 'sounders', 'goal', 'insane']
# ['hello', 'seattle', 'minecraft', 'earth', 'beta', '']
# ['walking', 'downtown', 'seattle']
# ['found', 'pike', 'place', 'seattle', 'washington', '']
# ['wish', 'rob', 'biren', 'seattle', 'tattoo', 'emporium', 'seattle', 'wa']
# ['view', 'seattle', 'commute', 'morning', '']
# ['seattle', 'sounders', '1', '0', 'atlanta', 'united', 'raul', 'ruidiaz', '58', '']
# ['los', 'angeles', 'angels', 'hit', 'seattle', 'mariners', 'honor', 'tyler', 'skaggs']
# ['shirt', 'seattle', 'aquarium', '']
# ['russell', 'westbrook', 'traded', '6', 'teams', 'lost', 'franchise', 'career', 'scoring', 'leader', 'offseason']
# ['magnitude', '4', '4', 'earthquake', 'shakes', 'seattle', 'overnight']
# ['list', 'us', 'politicians', 'charged', 'convicted', 'sex', 'crimes', 'minors']
# ['list', 'democrats', 'charged', 'convicted', 'sex', 'crimes']
# ['shirt', 'depicting', 'gps', 'route', 'words', 'shouted', 'seattle', 'jogger', 'fend', 'attacker', 'golden', 'gardens', '']
# ['kitchen', 'living', 'area', 'feature', 'floor', 'ceiling', 'windows', 'home', 'located', 'seattle', 'washington', '1729', 'x', '1425', '']
# ['kevin', 'durant', 'joined', 'every', 'team', 'lost', 'since', 'beginning', 'nba', 'career', '']
# ['rose', 'lavelle', 'watched', '2015', 'world', 'cup', 'final', 'pizza', 'shop', 'watching', 'handful', 'teammates', 'amateur', 'seattle', 'summer', 'league', 'team', 'struck', 'goal', 'probably', 'clinched', '2019', 'trophy', 'feelings', 'must', 'experience', 'dizzying', 'rise', 'born', 'dreams', 'skill', 'wonder', '']
# ['guy', 'pulled', 'car', 'help', 'struggling', 'elderly', 'couple', 'cross', 'road', 'west', 'seattle']
# ['seattle', 'patch', '1', 'earned', 'fishing', 'lime', 'bike', 'lake', 'union']
# ['finally', 'living', 'life', 'wanted', '29', 'years', 'mormonism', '6', 'years', 'openly', 'gay', 'looking', 'someone', 'us', 'pride', 'seattle', 'past', 'weekend', 'incredible', 'experience', 'around', 'many', 'people', 'want', 'equality', 'love', 'happy', '4th', 'exmos', '']
# ['happy', 'fourth', 'july', 'seattle', '']
# ['seattle', 'children', 'hospital', 'operating', 'rooms', 'shut', 'patient', 'dies', 'mold', 'infection']
# ['amazing', 'shot', 'wheel', 'lit', 'seattle', 'pride']
# ['boys', 'white', 'making', 'sure', 'everyone', 'safe', 'seattle', 'pride', 'parade']
# ['seattle', 'pride', '2019']
# ['joe', 'biden', 'challenged', 'crowd', 'suggesting', 'mocking', 'gay', 'waiter', 'socially', 'acceptable', 'five', 'years', 'ago', 'crowd', 'interjected', 'saying', 'seattle', '']
# ['marilyn', 'photographer', 'w', 'proud', 'boys', 'trying', 'dox', 'folks', 'seattle', 'transpride', '']
# ['best', 'view', 'flying', 'outof', 'seattle', 'mt', 'rainier', 'glory', '3684', 'x', '4360', 'oc', 'ig', 'uofalec']
# ['areas', 'check', 'seattle', 'red', 'cedars', 'street', 'm', 'staying', 'beautiful', '']
# ['neat', 'fact', 'kawhi', 'leonard', 'person', 'nba', 'history', 'win', 'multiple', 'finals', 'mvps', 'win', 'regular', 'season', 'mvp', '']
# ['seattle', 'disposition', 'according', 'seattle', 'times', 'writer']
# ['package', 'thieves', 'steal', 'replica', 'wwe', 'belts', '5', 'year', 'old', 'special', 'needs', 'boy', 'awaiting', 'surgery', 'seattle', 'area', 'folks', 'please', 'share']
# ['people', 'mark', 'origin', 'pins', 'seattle', 'cafe', '']
# ['photo', 'seattle', 'turned', 'pretty', 'good', 'opinion', '']
# ['nervous', 'post', 'know', 'won', 'get', 'much', 'love', 'due', 'seattle', 'hoody', 'titty', 'tuesday', 'mine', 'oc', '']
# ['garage', 'sale', 'find', '1929', '100', 'love', 'letters', 'two', 'years', 'guy', 'seattle', 'girl', 'aberdeen', 'wa', '']
# ['chick', 'fil', 'opening', 'first', 'seattle', 'location', 'week']
# ['awesome', 'dark', 'ritual', 'cosplay', 'mf', 'seattle', '']
# ['wife', 'powerful', 'executive', 'hate']
# ['iama', '25f', 'absolutely', 'body', 'hair', 'ama', '']
# ['downtown', 'seattle', 'really', 'crisp', 'retrowave', 'vibes', 'last', 'night']
# ['seattle', 'reigning', 'major', 'league', 'rugby', 'champions', 'seattle', 'seawolves', '']
# ['good', 'morning', 'valve', 'employees', '']
# ['brass', 'fish', 'floor', 'seattle', 'airport', 'one', 'suitcase']
# ['message', 'got', 'brother', 'lives', 'near', 'seattle', 'sanctuary', 'cities', 'need', 'banned', '']
# ['shift', 'supervisor', 'work', 'petty', 'tyrant', 'treated', 'like', 'garbage', 'got', 'fired', 'arrested', '']
# ['pacific', 'science', 'center', 'seattle', 'lego', 'art', 'exhibit', 'guests', 'encouraged', 'write', 'name', 'leave', 'lego', 'left']
# ['san', 'francisco', 'probably', 'one', 'worst', 'cities', 'america']
# ['let', 'ai', 'language', 'model', 'rank', 'top', 'quarterbacks', '2019', 'season']
# ['35', 'miles', 'mostly', 'continuous', 'dedicated', 'well', 'maintained', 'bike', 'lanes', 'well', 'done', 'seattle', 'gorgeous', 'ride', '']
# ['', 'passan', 'edwin', 'encarnación', 'traded', 'seattle', 'mariners', 'new', 'york', 'yankees', 'sources', 'familiar', 'deal', 'tell', 'espn', 'encarnación', 'currently', 'leads', 'american', 'league', '21', 'home', 'runs', 'mariners', 'teardown', 'full', 'bloom', 'yankees', 'get', 'another', 'big', 'bat', '']
# ['', 'u', 'magic_fingers', 'gives', 'comparison', 'problem', 'homelessness', 'vancouver', 'seattle']
# ['current', 'state', 'men', 'seattle', '2019', '']
# ['foggy', 'evening', 'seattle']
# ['raptors', 'win', 'tonight', 'serge', 'ibaka', 'recent', 'player', 'drafted', 'seattle', 'supersonics', 'player', 'win', 'nba', 'title', '']
# ['', 'siciliano', 'earl', 'thomas', 'raven', 'defense', 'complex', 'compared', 'seattle', 'ran', 'cover', '3', 'time', '']
# ['exposed', 'despite', 'toronto', 'claim', 'north', 'scotiabank', 'arena', '3rd', 'northern', 'nba', 'arena']
# ['mt', 'rainer', 'seen', 'university', 'washington', 'seattle', 'washington', 'oc', '3456x4320', '']
# ['tried', 'give', 'seattle', 'different', 'vibe', 'night']
# ['seattle', 'set', 'increase', 'fees', 'developers', 'let', 'properties', 'sit', 'empty', 'go', 'derelict']
# ['tlc', 'version', 'seattle', 'seems', 'oddly', 'familiar']
# ['world', 'war', 'ii', 'veteran', 'welcomed', 'seattle', 'mariners', 'game', 'receives', 'standing', 'ovation', 'crowd', '']
# ['world', 'war', 'ii', 'veteran', 'welcomed', 'seattle', 'mariners', 'game', 'receives', 'standing', 'ovation', 'crowd', '']
# ['world', 'war', 'ii', 'veteran', 'welcomed', 'seattle', 'mariners', 'game', 'receives', 'standing', 'ovation', 'crowd', '']
# ['world', 'war', 'ii', 'veteran', 'welcomed', 'seattle', 'mariners', 'game', 'receives', 'standing', 'ovation', 'crowd', '']
# ['bernie', 'oligarchy', 'looks', 'like', 'amazon', 'used', 'enormous', 'wealth', 'power', 'kill', 'tax', 'build', 'affordable', 'housing', 'seattle', 'one', 'year', 'later', 'thousands', 'people', 'live', 'streets', 'city', 'continues', 'struggle', 'crisis', '']
# ['buddies', 'going', 'gp', 'seattle', 'made', 'us', 'team', 'shirt', 'featuring', 'us', 'magic', 'iconic', '2', 'drops', '']
# ['seattle', 'sockeyes', 'concepts', 'using', 'website', 'colors', 'ldconcepts', '']
# ['found', 'near', 'volunteer', 'park', 'seattle', '']
# ['1984', 'someone', 'brutally', 'murdered', 'single', 'mother', 'patricia', 'dixon', 'five', 'year', 'old', 'daughter', 'amanda', 'dream', 'vacation', 'disneyland', '']
# ['helloooo', 'seattle', 'let', 'land', 'puppy', 'right', 'sailboats', '']
# ['seattle', 'gets', 'thumbs', '']
# ['appreciation', 'thread', 'raptors', 'home', 'crowd', '']
# ['plane', 'crashing', 'onto', 'highway', 'near', 'seattle', '']
# ['one', 'cold', 'hard', 'truth', 'nfl', 'team', '2019']
# ['check', 'asian', 'patriot', 'wearing', 'maga', 'hat', 'speaks', 'rally', 'muslim', 'rep', 'ilhan', 'omar', 'seattle', 'ramadan', 'fundraiser', 'w', 'cair', 'ain', 'backing', 'appreciate', 'cynical', 'lady', 'trash', 'americans', 'link', 'comments']
# ['snap', 'photo', 'guy', 'toting', 'good', 'boi', 'today', 'folk', 'life', 'seattle', '']
# ['25', 'years', 'seattle', 'finally', 'got', 'space', 'needle', '']
# ['playtest', 'cards', 'display', 'museum', 'pop', 'culture', 'seattle', '']
# ['til', '1974', 'girlfriend', 'ted', 'bundy', 'called', 'seattle', 'police', 'tell', 'matched', 'description', 'suspect', 'several', 'murder', 'cases', 'hung', 'told', 'need', 'come', 'fill', 'report', 're', 'busy', 'talk', 'girlfriends', 'phone', 'would', 'kill', 'many', 'women', '']
# ['bill', 'gates', 'dick', 'burgers', 'seattle', 'washington', 'waiting', 'line', 'place', 'order', 'bro', 'worth', '95', 'billion', 'runs', 'largest', 'charity', 'world', 'still', 'stand', 'line', 'like', 'rest', 'us', 'burger', 'fries', 'coke', 'winner', 'life', 'right', '']
# ['downtown', 'seattle', 'november', '2016']
# ['someone', 'seattle', 'us', 'favor', '']
# ['flying', 'around', 'seattle', 'right', '']
# ['heptapod', 'crew', 'checking', 'human', 'jason', 'middelton', 'true', 'love', 'seattle', 'wa', '']
# ['ever', 'wondered', 'hiring', 'process', '20', 'years', 'ago', 'compared', 'today', 'probably', 'tell', 'anyway', '']
# ['seattle', 'scores', 'climate', 'change', 'strategies', 'says', 'environmental', 'group']
# ['roadtripping', 'chicago', 'seattle', 'via', 'glacier', 'national', 'park']
# ['', 'oc', 'jaguargator9', 'weird', 'stat', 'thread', 'eurovision', '2019', 'edition']
# ['space', 'needle', 'moonrise', 'tonight', 'seattle', 'oc', '']
# ['looking', 'towards', 'seattle', 'sky', '2210x2762', 'oc', '']
# ['oh', 'seattle', 'part', '2', '']
# ['seattle', '1', '0', 'houston', 'cristian', 'roldan', 'great', 'goal', '5', '']
# ['spotted', 'seattle']
# ['giant', 'man', 'wreaks', 'havok', 'seattle']
# ['south', 'seattle', 'transfer', 'station', 'saw', 'think', 'amazon', 'go', 'would', 'least', 'compost', 'unsold', 'food', '']
# ['best', 'doctor', 'salem', 'seattle']
# ['meanwhile', 'seattle', 'washington']
# ['garden', 'apartment', 'living', 'room', 'seattle', 'wa']
# ['gentleman', 'fight', 'seattle', 'ihop']
# ['always', 'loved', 'perspective', 'seattle', 'finally', 'decided', 'photograph', 'last', 'week', '']
# ['seattle', 'tacoma', 'bremerton', 'night', 'photographed', 'international', 'space', 'station']
# ['seattle', 'enters', 'league', 'nhl', 'schedule', 'one', 'game', 'pre', 'season', 'montreal', 'finally', 'decide', '1919', 'stanley', 'cup', 'winner']
# ['entitled', 'mom', 'stalks', 'grocery', 'store', 'bag']
# ['looking', 'apartment', 'seattle', '']
# ['ice', 'cube', 'clippers', 'chance', 'take', 'city', 'need', 'go', 'think', 'seattle', 'really', 'loves', 'basketball', 'jump']
# ['6', '05', 'seattle', 'downtown', 'morning', 'everyone', '']
# ['', 'u', '518peacemaker', 'crane', 'operator', 'uses', 'dashcam', 'footage', 'identify', 'negligence', 'seattle', 'crane', 'collapse', '']
# ['', 'usa', 'dashcam', 'crane', 'collapse', 'seattle', '4', '27', 'start', '17sec', '']
# ['dashcam', 'video', 'seattle', 'crane', 'collapse']
# ['4', 'dead', '4', 'injured', 'construction', 'crane', 'collapses', 'busy', 'seattle', 'street']
# ['presidents', 'usa', 'lump', '90', 'alternative', 'seattle', 'post', 'grunge', '']
# ['went', 'coffee', 'shop', 'seattle', 'knew', 'good']
# ['crane', 'collapses', 'seattle', 'traffic', '4', '27', '19', 'killing', 'four']
# ['ap', 'news', 'latest', 'crane', 'collapses', 'downtown', 'seattle', 'kills', '4']
# ['old', 'brick', 'roads', 'seattle', 'popping', 'underneath', 'damaged', 'asphalt']
# ['seattle', 'space', 'needle', 'tristan', 'zhou', '2500x3125', '']
# ['guy', 'seattle', 'parading', 'sign', 'read', 'jesus', 'said', 'walked', 'one', 'yelled', 'walked', 'away', 'well', 'one', 'loves', '']
# ['know', 'seattle', 'wildflowers', 'full', 'bloom', 'gorge', '']
# ['dear', 'seattle', 'appreciate', 'culture', 'minding', 'damn', 'business']
# ['saw', 'melted', 'cat', 'seattle']
# ['happy', 'earth', 'day', 'lucky', 'shot', 'captured', 'flying', 'back', 'seattle', '']
# ['cruise', 'ship', 'currently', 'docked', 'seattle', 'gokart', 'track', 'roof']
# ['yesterday', 'seattle', '']
# ['seattle', 'city', 'council', 'priorities']
# ['special', 'dad', 'controls', 'engineer', 'rainier', 'brewery', 'seattle', 'washington', 'closed', '1999', 'handed', 'line', 'last', 'cans', 'run', 'brewery', 'shut', 'bottom', 'stamped', 'july', '02', '1999', 'last', 'true', 'rainier', '']
# ['yup', '4', '20', 'seattle', '']
# ['ridership', 'jumped', '400', 'seattle', 'protected', 'bike', 'lane']
# ['seattle', 'facebook', 'blocks', 'political', 'ads', 'one', 'city', 'council', 'candidate', 'running', 'ads', 'opponent']
# ['vancouver', 'beautiful', 'city', 'ever', 'visited', 'didn', 'even', 'feel', 'real', '']
# ['seattle', 'seahawks', 'russell', 'wilson', 'reached', 'agreement', 'four', 'year', '140', 'million', 'extension', 'making', 'quarterback', 'highest', 'paid', 'player', 'nfl']
# ['', 'rapoport', 'full', 'details', 'seahawks', 'qb', 'russell', 'wilson', '4', 'new', 'years', '140m', '65m', 'sign', 'total', 'guarantee', '107m', 'trade', 'clause', 'wilson', 'contract', '5', 'years', '157m', 'staying', 'seattle', '']
# ['', 'wilson', 'seattle', 'let', 'get', '']
# ['us', 'olympic', 'medalist', 'rebecca', 'twig', 'found', 'homeless', 'seattle']
# ['', 'rapoport', 'today', 'deadline', 'long', 'term', 'deal', 'seahawks', 'qb', 'russell', 'wilson', 'agent', 'mark', 'rodgers', 'ground', 'seattle', 'last', '3', 'days', 'negotiate', 'team', 'brass', 'working', 'time', 'running', 'offseason', 'conditioning', 'begins']
# ['like', 'food', 'hottest', 'hot', 'sauce', 'world', '']
# ['1999', 'mother', 'took', '12', 'hour', 'h', '1b', 'visa', 'job', 'could', 'escape', 'gun', 'violence', 'south', 'africa', 'm', 'ceo', 'startup', 'uses', 'ai', 'save', 'lives', 'active', 'shooter', 'incidents', 'ama', '']
# ['seattle', 'mayor', 'responds', 'president', 'trump', 'city', 'isn', 'afraid', 'immigrants', '']
# ['also', 'gyarados', 'tattoo', 'done', 'scott', 'falbo', 'studio', 'arcanum', 'seattle', 'wa']
# ['found', 'seattle', 'themed', 'coffee', 'shop', 'visiting', 'fargo', 'nd', 'sure', 'less', 'random', 'rainer', 'latte', 'japan', 'post', '']
# ['seattle', 'mariners', 'homered', 'first', '15', 'games', 'new', 'major', 'league', 'record']
# ['living', 'within', 'budget', 'incredibly', 'liberating']
# ['behold', 'great', 'wheel', 'seattle', 'wa', '3593x5922', '']
# ['man', 'middle', 'kevin', 'kevin', 'volunteered', '24', 'days', 'life', 'drive', 'high', 'school', 'band', 'seattle', 'san', 'diego', 'compete', 'band', 'competitions', 'kevin', 'gave', 'opportunity', 'kids', 'bring', 'home', 'gold', 'back', 'seattle', 'thank', 'kevin', 'without', 'would', 'possible', '']
# ['7', 'years', 'van', 'dwelling', '7', 'lessons', 'facts', 'observations']
# ['new', 'seattle', 'living', 'space', 'finally', 'upgraded', 'studio', 'life', 'first', 'adult', 'apartment', '']
# ['current', 'anti', 'trump', 'protest', 'seattle', 'turnout', 'maybe', '30', 'people', '']
# ['bald', 'eagles', 'taking', 'trash', 'seattle', 'landfill', 'dumping', 'suburban', 'yards']
# ['seattle', 'starter', 'home', '']
# ['', 'bell', 'nothing', 'changed', 're', 'seahawks', 'russell', 'wilson', 'wilson', 'commanding', 'eventually', 'get', 'nfl', 'richest', 'deal', 'north', 'aaron', 'rodgers', '33', '5m', '98', '2m', 'gtd', 'seattle', 'plan', 'b', 'team', 'budgeting', 'everything', 'else', 'leveraging', 'posturing', 'window', 'dressing']
# ['first', 'time', 'mariners', 'history', 'seattle', 'mariners', 'started', 'season', '7', '1']
# ['saving', 'airfare', 'sql', 'exploits']
# ['abusive', 'spouse', 'attempts', 'commit', 'bigamy', 'putting', 'hell', 'revenge', 'commences', 'oc', 'nuclear', 'revenge', '']
# ['', 'post', 'series', 'thread', 'seattle', 'mariners', 'take', '3', '4', 'boston', 'red', 'sox']
# ['', 'ok', 'white', 'sign', 'downtown', 'seattle', 'social', 'experiment', '']
# ...
# ['', 'match', 'thread', 'ghana', 'vs', 'united', 'states', 'america', 'group', 'g']
# ['seattle', 'student', 'credited', 'stopping', 'campus', 'gunman', 'wedding', 'registry', 'honeymoon', 'paid', 'strangers']
# ['ggg', 'hero', 'jon', 'meis', 'seattle', 'pacific', 'university', '']
# ['shooting', 'seattle', 'pacific', 'university', '4', 'wounded', 'post', '']
# ['seattle', 'police', 'right', '']
# ['seattle', 'police', 'seize', '2k', 'illegally', 'grown', 'pot', 'plants', 'didn', 'arrest', 'anyone', 'said', 'interested', 'bringing', 'operation', 'numbers', 'legal', 'limits', 'let', 'growers', 'pick', 'plants', 'wanted', 'keep', '']
# ['seattle', 'police', 'uncover', 'one', 'largest', 'marijuana', 'grow', 'operations', 'ever', 'seen', 'made', 'arrests', 'even', 'let', 'grower', 'decide', '45', 'plants', 'wanted', 'keep', 'order', 'compliance', 'state', 'law', '']
# ['new', 'york', 'seattle', 'holding', 'silent', 'reading', 'parties']
# ['seattle', '1536', '1033', '']
# ['dear', 'united', 'states', 'america', 're', 'net', 'neutrality', 'think', 'takes', 'free', 'democratic', 'society', 'anymore', '']
# ['distribute', 'prize', 'pool', 'year']
# ['texas', 'longhorns', 'taken', 'nfl', 'draft']
# ['chibiham', 'juicy', 'aftertaste', 'ending', '']
# ['seattle', 'announces', '15', 'minimum', 'wage', 'highest', 'u', '']
# ['incredible', 'image', 'seattle', 'taken', 'atop', 'space', 'needle', '']
# ['seattle', 'starry', 'night']
# ['barbara', 'ehrenreich', 'writer', 'journalist', 'best', 'known', 'book', 'probably', 'nickel', 'dimed', 'ama', '']
# ['seattle', 'mayor', 'allow', 'internet', 'access', 'managed', 'private', 'monopoly', '']
# ['moved', 'back', 'seattle', 'morning', '3', 'years', 'away', 'snapped', 'stunning', 'photo', 'descent', 'welcome', 'home', '']
# ['found', 'seattle', 'today']
# ['boyfriend', 'flannel', 'check', 'pearl', 'jam', 'shirt', 'check', 'seattle', '1992']
# ['found', 'seattle', 'thought', 'guys', '']
# ['found', 'interesting', 'grocery', 'near', 'house', 'seattle', '']
# ['seattle', 'skyline', '']
# ['photos', 'helicopter', 'crash', 'seattle', 'today', '']
# ['happened', 'visited', 'seattle', 'still', 'idea', 'said', '']
# ['til', 'early', '90', 'younger', 'bill', 'nye', 'appeared', 'seattle', 'sketch', 'show', 'almost', 'live', 'corrected', 'host', 'pronunciation', 'gigawatt', 'jigowatt', 'host', 'replied', 'think', 'bill', 'nye', 'science', 'guy', 'nickname', 'stuck', '']
# ['hipster', 'sitting', 'next', 'metro', 'seattle', 'bus', 'morning', 'mangled', 'copy', 'grapes', 'wrath', 'could', 'look', 'like', 'reading', 'actually', 'playing', 'game', 'boy', '']
# ['seattle', 'gamer', 'notices', 'connection', 'steam', 'high', 'latency', 'hop', 'despite', 'everyone', 'else', 'telling', 'unlikely', 'resolved', 'networking', 'hero', 'works', 'isp', 'notices', 'resolves', 'problem', '']
# ['unique', 'view', 'seattle', 'x', 'post', 'r', 'seattle', '1343x836', '']
# ['unique', 'seattle', 'view']
# ['great', 'burger', 'seattle', 'highly', 'recommended', '3264', 'x', '2448', 'oc', '']
# ['live', 'seattle', 'get', 'routed', 'washington', 'colorado', 'back', 'wa', 'valve', 'seattle', 'game', 'server', '']
# ['got', 'hotel', 'room', 'seattle', 'found', 'stuck', 'wall', 'welcome', 'city', '']
# ['starfish', 'literally', 'ripping', 'apart', 'pacific', 'coast', 're', 'environment', 'journalist', 'diver', 'videographer', 'reporting', 'mysterious', 'disease', 'ask', 'us', 'anything', '']
# ['lost', 'wood', 'seattle', 'wa', '3204', 'x', '2136', '']
# ['seattle', 'box', 'remodel', '1120x747', '']
# ['met', 'guy', 'seattle', '']
# ['til', 'hotel', 'bar', 'seattle', 'hosts', 'silent', 'reading', 'night', 'month', 'apparently', 'popular', '']
# ['meet', 'meatasaurus', 'butchers', 'uwajimaya', 'seattle', '']
# ['think', 'us', 'bartenders', 'seattle', 'felt', 'last', 'night']
# ['everyone', 'seattle', 'today']
# ['game', 'thread', 'seattle', 'seahawks', '13', '3', 'denver', 'broncos', '13', '3', '2nd', 'quarter', '']
# ['original', 'backup', 'sputnik', 'satellite', 'museum', 'flight', 'seattle', '1260x900', 'oc', '']
# ['', 'fluff', 'seattle', 'might', 'pretty', 'good', 'defense', 'base', 'stat', 'm', 'betting', 'denver', 'high', 'attack', 'stat']
# ['whether', 're', 'denver', 'bronco', 'seattle', 'seahawk', '']
# ['hearing', 'impaired', 'little', 'girl', 'writes', 'seattle', 'seahawks', 'fb', 'derrick', 'coleman', 'coleman', 'ggg', 'writes', 'nice', 'letter', 'back', '']
# ['post', 'game', 'thread', 'san', 'francisco', '49ers', '12', '4', 'seattle', 'seahawks', '13', '3', '']
# ['denver', 'seattle', 'win', 'today', 'two', 'teams', 'states', 'legalized', 'marijuana', 'giving', 'whole', 'new', 'meaning', 'term', 'super', 'bowl', '']
# ['game', 'thread', 'new', 'orleans', 'saints', '11', '5', 'seattle', 'seahawks', '13', '3', '']
# ['graffiti', 'local', 'interstate', 'repost', 'r', 'seattle', '']
# ['like', 'living', 'seattle', 'rest', 'country', 'frozen', '']
# ['nfl', 'fined', 'seahawks', 'rb', 'marshawn', 'lynch', '50', '000', 'speaking', 'media', 'throughout', 'season', 'per', 'seattle', 'source', '']
# ['survey', 'results', '']
# ['re', 'moving', 'seattle', 'next', 'fall', 'trying', 'prepare', '']
# ['seattle', 'fog']
# ['seattle', 'deploy', 'gigabit', 'fiber', 'network']
# ['oatmeal', 'strikes', 'x', 'post', 'r', 'funny', 'x', 'post', 'r', 'geek', 'x', 'post', 'r', 'technology', 'x', 'post', 'r', 'atheism', 'x', 'post', 'r', 'comics', 'x', 'post', 'r', 'science', 'x', 'post', 'r', 'gaming', 'x', 'post', 'r', 'trees', 'x', 'post', 'r', 'seattle', 'x', 'post', 'r', 'dogs', 'x', 'post', 'r', 'justiceporn', '']
# ['seattle', 'graffiti']
# ['seattle', 'festive', '']
# ['mt', 'rainier', 'shot', 'super', 'telephoto', 'lens', 'space', 'needle', 'seattle', 'roughly', '60', 'miles', 'away', '1500x1000', 'oc', '']
# ['', 'police', 'department', 'believes', 'state', 'law', 'may', 'responsibly', 'get', 'baked', 'order', 'pizzas', 'enjoy', 'lord', 'rings', 'marathon', 'privacy', 'home', 'want', 'seattle', 'police', 'department']
# ['get', 'high', 'us', 'x', 'post', 'r', 'seattle', '']
# ['uncle', 'started', 'marshmallow', 'company', 'made', 'seattle', 'news', 'sole', 'owner', 'cook', 'thought', 'guys', 'may', 'like', 'try', 'stuff', '']
# ['15', 'minute', 'difference', 'seattle', 'weather']
# ['beef', 'onion', 'cheese', 'piroshky', 'piroshky', 'piroshky', 'seattle', 'next', 'original', 'starbucks', '2591', 'x', '1935', '']
# ['til', 'seattle', 'police', 'dept', 'tl', 'dr', 'smoking', 'pot', 'website', '']
# ['winter', 'seattle', 'dusk', '']
# ['', '12', 'nugs', 'sale', 'seattle']
# ['seattle', 'superhero', 'phoenix', 'jones', 'knocks', 'dude']
# ['phoenix', 'jones', 'costumed', 'leader', 'seattle', 'crime', 'prevention', 'group', 'knocks', 'assault', 'suspect', '']
# ['public', 'service', 'announcement', 'washington', 'ents', '502', 'doesn', 'start', 'taking', 'effect', 'another', 'month', 'short', 'marijuana', 'still', 'illegal', 'right', '']
# ['reddit', 'look', 'halloween', 'costume', 'reddit', 'look', 'halloween', 'costume', 'reddit', 'look', 'halloween', 'costume', 'reddit', 'look', 'halloween', 'costume', 'reddit', 'look', 'halloween', 'costume', 'reddit', 'look', 'halloween', 'costume', 'reddit', 'look', 'halloween', 'costume', 'reddit', 'look', 'halloween', 'costume', 'reddit']
# ['well', 'unexpected', '']
# ['drive', 'food', 'truck', 'seattle', 'last', 'week', 'nerd', 'customer', 'think', 'see', '']
# ['m', 'character', 'actor', 'appeared', '200', 'tv', 'shows', 'films', 'name', 'stephen', 'tobolowsky', 'reddit', 'account', 'passport', 'verify', 'ama', '']
# ['pier', '54', 'seattle']
# ['m', 'visiting', 'seattle', 'weekend', 'found', 'want', 'spend', 'rest', 'trip', '']
# ['dog', 'disappeared', '6', '5', 'years', 'ago', 'turned', 'reunion', '']
# ['giant', 'harvestmen', 'take', 'rooftops', 'seattle']
# ['askscience', 'special', 'ama', 'encyclopedia', 'dna', 'elements', 'encode', 'consortium', 'last', 'week', 'published', '30', 'papers', 'giant', 'collection', 'data', 'function', 'human', 'genome', 'ask', 'us', 'anything', '']
# ['seattle', 'redditors', 'get', 'others', 'backs']
# ['currently', 'driving', 'boston', 'seattle', 'eastern', 'montana', 'met', 'fellow', 'rest', 'stop', 'biking', 'seattle', 'nyc', '']
# ['seattle', 'raining', 'didn', 'believe', 'either', '']
# ['guild', 'wars', '2', 'status', 'thursday', 'august', '30']
# ['guild', 'wars', '2', 'status', 'wednesday', 'august', '29']
# ['need', 'get', 'bill', 'nye', 'science', 'guy', 'netflix', 'instant', 'viewing', 'make', 'happen', '']
# ['earl', 'alexander', 'voice', 'louis', 'left', '4', 'dead', 'ama', '']
# ['first', 'guitar', 'kurt', 'cobain', 'smashed', 'stage', 'two', 'halves', 'previously', 'belonged', 'two', 'different', 'owners', 'later', 'came', 'together', 'donated', 'emp', 'museum', 'seattle', '']
# ['got', 'bong', 'yesterday', 'seattle', 'hempfest', '2012', 'decided', 'name', 'bong', 'beetlejuice', '']
# ['bike', 'owner', 'portland', 'bike', 'stolen', 'tracks', 'craigslist', 'seattle', 'confronts', 'thief', 'gets', 'bike', 'back', 'good', 'day', '']
# ['', 'steal', 'bikes', 'bro', 'seattle', 'edition', 'long', 'watch', 'justice', 'served', '']
# ['name', 'daniel', 'spent', 'summer', 'traveling', 'things', 'redditors', 'slept', 'floors', 'couches', 'complete', 'strangers', 'never', 'spent', 'seven', 'days', 'given', 'city', 'ama']
# ['got', 'love', 'seattle', 'puget', 'sound', 'ferry', 'seattle', 'skyline', 'mount', 'rainier', 'distance']
# ['', 'update', 'survived', 'need', 'help', 'getting', 'something', 'done', 'unlimited', 'flight', 'benefits', 'summer', 'want', 'spend', 'summer', 'helping', 'redditors']
# ['ferrell', 'zach', 'galifianakis', 'serving', 'coffee', 'seattle', '']
# ['quit', 'job', 'rode', 'motorcycle', '48', 'u', 'states', '100', 'days', 'ama']
# ['quit', 'job', 'broke', 'long', 'time', 'girlfriend', 'traveled', 'us', 'train', 'two', 'months', 'alone', 'staying', 'random', 'people', 'met', 'internet', 'days', 'advance', 'made', 'ama', 'exactly', 'year', 'ago', 'today', 'made', 'promise', 'm', 'back', 'ama', '']
# ['japanese', 'family', 'returning', 'home', 'seattle', 'washington', 'relocation', 'center', 'camp', 'hunt', 'idaho', 'may', '10', '1945', '990x748', 'os', '']
# ['seattle', 'zombie', 'walk', '2012', '']
# ['olympics', 'coming', 'tons', 'commercials', 'asking', 'viewers', 'donate', 'us', 'olympic', 'committee', 'please', '']
# ['found', 'abraham', 'lincoln', 'seattle']
# ['wore', 'clothes', '56', 'days', 'someone', 'finally', 'said', 'something', 'amateur', 'psychology', 'experiments', 'done', '']
# ['found', 'shop', 'seattle']
# ['jordan', 'weisman', 'creator', 'shadowrun', 'mechwarrior', 'crimson', 'skies', 'ama']
# ['watching', 'solar', 'eclipse', 'seattle']
# ['watching', 'solar', 'eclipse', 'seattle', '']
# ['', 'effortpost', 'convert', 'upvotes', 'awesome', 'video', 'game', '']
# ['', 'update', 'need', 'help', 'getting', 'something', 'done', 'unlimited', 'flight', 'benefits', 'summer', 'want', 'spend', 'summer', 'helping', 'redditors', '']
# ['seattle', 'local', 'superhero', 'named', 'phoenix', 'jones', 'came', 'today', 'shit', 'got', 'real', '']
# ['doesnt', 'always', 'rain', 'seattle', 'nope', '']
# ['happy', '4', '20', 'fellow', 'seattle', 'ents', '']
# ['iama', 'directory', 'engineering', 'canonical', 'manage', 'ubuntu', 'engineering', 'team', 'ama']
# ['til', '1909', 'world', 'fair', 'seattle', '1', 'month', 'old', 'baby', 'given', 'away', 'raffle', 'one', 'knows', 'happened', '']
# ['inhabited', 'tree', 'house', 'seattle', 'washington']
# ['took', 'son', 'seattle', 'aquarium', 'yesterday', 'submit', 'consideration', 'river', 'otter', 'sucking', 'tail', 'sleeping', '']
# ['seattle', 'police', 'officer', 'threatens', 'make', 'evidence', 'arrest', 'innocent', 'men', '']
# ['james', 'fallows', 'national', 'correspondent', 'atlantic', 'long', 'ago', 'speechwriter', 'long', 'ago', 'president', 'jimmy', 'carter', 'ama']
# ['years', 'ago', 'one', 'worst', 'days', 'life', 'decided', 'chill', 'seattle', 'aquarium', 'watched', 'otter', 'fall', 'asleep', 'sucking', 'tail', 'made', 'day', 'much', 'better', '']
# ['friends', 'dealt', 'snow', 'seattle', '']
# ['snows', 'seattle', '']
# ['2', 'seattle', 'wa', 'cops', 'dashcam', 'dragging', 'passenger', 'car', 'tasing', 'refusing', 'give', 'id', 'legally', 'didn', 'arresting', 'mom', 'telling', 'call', 'supervisor', '']
# ['whats', 'wierdest', 'thing', 'walked', 'possibly', 'nsfw', '']
# ['maybe', 'make', 'think', 'twice', 'november', '15th', 'jennifer', 'fox', 'kicked', 'stomach', 'pepper', 'sprayed', 'seattle', 'police', 'three', 'months', 'pregnant']
# ['pregnant', 'woman', 'pepper', 'sprayed', 'cops', 'seattle', 'ows', 'protest', 'miscarried']
# ['84', 'year', 'old', 'ows', 'supporter', 'pepper', 'sprayed', 'seattle', 'washington']
# ['84', 'year', 'old', 'woman', 'becomes', 'pepper', 'sprayed', 'face', 'occupy', 'seattle']
# ['lighter', 'note', 'yesterday', '9', 'seattle', 'city', 'counsel', 'members', 'spoke', 'support', 'occupy', 'movement', 'voted', 'unanimously', 'move', 'city', 'money', 'big', 'banks', 'small', 'local', 'credit', 'unions', '']
# ['today', 'received', 'non', 'stop', 'phone', 'calls', 'emails', 'internet', 'pitchfork', 'mob', 'started', 'r', 'gaming', '']
# ['occupy', 'wall', 'streeet', 'nyc', 'raided', 'nypd', 'speak', 'single', '24', 'hour', 'news', 'channel', 'covering', '']
# ['jurassic', 'park', 'jeep', '']
# ['let', 'telltale', 'borrow', 'jurassic', 'park', 'jeep', 'got', 'lousy', 'dino', 'damage', '']
# ['outraged', 'going', 'america', 'right', 'read', '']
# ['arrested', '700', 'new', 'york', 'raided', 'sf', 'raided', 'boston', 're', 'raid', 'seattle', 'tipping', 'point', 'arrived', 'movement', 'grow', 'stronger', 'fools']
# ['past', 'two', 'months', 'nearly', '18', '000', 'seattle', 'area', 'residents', 'ditched', 'corporate', 'banks', 'local', 'credit', 'union', '']
# ['hey', 'reddit', 'help', 'ken', 'jennings', 'write', 'next', 'book', 'well', 'meaning', 'things', 'parents', 'tell', 'kids', 'without', 'idea', 're', 'actually', 'true', '']
# ['recently', 'drove', 'seattle', 'maine', 'took', 'photo', 'every', '90', 'seconds', 'enjoy', 'time', 'lapse', '']
# ['seattle', 'geek', 'gets', 'banned', 'comcast', 'year', 'using', 'much', 'data', 'using', 'cloud', 'services', 'amazon', 'new', 'music', 'service', 'going', 'quietly', 'arguing', 'comcast', 'abusing', 'monopoly', 'seattle', '']
# ['quit', 'job', 'ended', '4yr', 'relationship', 'traveled', '61', 'days', 'around', 'us', 'via', 'train', 'living', 'suitcase', 'couchsurfing', 'entire', 'way', 'got', 'back', 'ama']
# ['r', 'seattle', 'meetup', '2011', 'fuck', 'yeah', '']
# ['seattle', 'pays', '1', '5m', 'family', 'hearing', 'impaired', 'woodcarver', 'shot', 'killed', 'police', 'dashcam', 'records', '4', 'seconds', 'warning', 'behind', 'shooting', 'man', 'back']
# ['iama', 'bus', 'driver', 'king', 'county', 'metro', 'seattle', 'shot', 'twice', 'threatened', 'knife', 'puked', 'ect', 'ect', 'stories', 'told', 'ama']
# ['anyone', 'seen', 'penguin', 'desperate', '']
# ['long', 'shot', 'sushi', 'chefs', 'need', 'job', 'seattle', 'area', 'need', 'one', '2', 'days', '']
# ['seattle', 'buses', 'set', 'carry', 'signs', 'saying', 'us', 'tax', 'dollars', 'support', 'israeli', 'war', 'crimes', 'tv', 'station', 'wonders', 'even', 'allowed', 'bus', 'company', 'attack', 'usual', 'suspects', 'online', 'poll', '']
# ['heart', 'tells', 'find', 'boys', 'young', 'men', 'know', 'following', 'inner', 'voice', '']
# ['reddit', 'beg', 'society', 'sake', 'buy', 'civilization', 'v', '']
# ['many', 'people', 'reddit', 'want', 'go', 'rally', 'restore', 'sanity', 'march', 'keep', 'fear', 'alive', 'cannot', 'live', 'far', 'away', 'inconvenience', 'would', 'solved', 'rally', 'closer', '']
# ['found', 'seattle', 'parking', 'lot', 'hmm', 'someone', 'grocery', 'list', 'wait', '']
# ['comedy', 'central', 'cut', 'portion', 'south', 'park', 'episode', 'following', 'death', 'threat', 'radical', 'muslim', 'group', 'seattle', 'cartoonist', 'molly', 'norris', 'wanted', 'counter', 'fear', 'declared', 'may', '20th', 'everybody', 'draw', 'mohammed', 'day', '']
# ['seattle', 'hacker', 'catches', 'cops', 'hid', 'arrest', 'tapes']
# ['reddit', 'met', 'guy', 'plane']

# %% [markdown]
# Let's make an empty Counter, loop through the Reddit posts, and add the tokenized words to the Counter for each post.

# %%
seattle_counts = Counter()

for post in seattle_posts:
    words = tokenize_words(post)
    seattle_counts.update(words)

# %%
pdx_counts = # Your code here

for post in pdx_posts:
    # Your code here — tokenize the words and assign the resulting list to a variable
    pdx_counts.update(words)

# %% [markdown]
# Check to see if you made the dictionaries correctly:

# %%
seattle_counts
# Out:
# Counter({'seattle': 1551,
#          'votes': 7,
#          'decriminalize': 3,
#          'psilocybin': 1,
#          'similar': 1,
#          'substances': 1,
#          'diamantenhände': 4,
#          'german': 4,
#          'market': 10,
#          'open': 12,
#          '': 1170,
#          'anyone': 8,
#          'else': 6,
#          'enjoy': 9,
#          'comparing': 1,
#          'real': 16,
#          'game': 78,
#          'pioneer': 2,
#          'place': 13,
#          'ace': 5,
#          'hardware': 3,
#          'lake': 7,
#          'city': 76,
#          'enforces': 1,
#          'mask': 3,
#          'policy': 3,
#          'fight': 5,
#          'mandate': 2,
#          'employee': 3,
#          'wa': 93,
#          'tries': 1,
#          'enforce': 1,
#          'bat': 4,
#          'arnold': 1,
#          'seahawks': 85,
#          'jamal': 1,
#          'adams': 1,
#          'expected': 5,
#          'participate': 1,
#          'mandatory': 1,
#          'minicamp': 1,
#          'looks': 15,
#          'sign': 15,
#          'contract': 5,
#          'extension': 5,
#          'eagle': 2,
#          'taking': 8,
#          'walk': 5,
#          'rain': 9,
#          'low': 2,
#          'tide': 3,
#          'west': 18,
#          'new': 74,
#          '315': 1,
#          'ship': 5,
#          'shore': 1,
#          'cranes': 3,
#          'inbound': 3,
#          'yesterday': 9,
#          'aboard': 1,
#          'zhen': 1,
#          'hua': 1,
#          '36': 4,
#          'welded': 1,
#          'deck': 1,
#          'former': 16,
#          'tanker': 1,
#          '50': 8,
#          'ballast': 1,
#          'tanks': 1,
#          'water': 8,
#          'dicks': 1,
#          'burgers': 2,
#          'offering': 2,
#          'livable': 1,
#          'wage': 15,
#          'great': 14,
#          'benefits': 3,
#          'affordable': 3,
#          'food': 14,
#          'truck': 5,
#          'wheels': 1,
#          'stolen': 9,
#          'stranger': 1,
#          'offers': 3,
#          'spares': 1,
#          'free': 17,
#          'first': 64,
#          'tattoo': 29,
#          'done': 19,
#          'mia': 1,
#          'ink': 2,
#          'washington': 61,
#          'overpass': 1,
#          'vibes': 2,
#          'oc': 60,
#          '3968x4960': 1,
#          'kleiman': 1,
#          'rift': 1,
#          'russell': 14,
#          'wilson': 20,
#          'happening': 4,
#          'believes': 3,
#          'top': 15,
#          '5': 44,
#          'qb': 14,
#          'time': 46,
#          'also': 19,
#          'isn': 7,
#          'currently': 8,
#          'even': 8,
#          'viewed': 1,
#          '10': 27,
#          'thinks': 2,
#          'holding': 4,
#          'back': 54,
#          'certain': 2,
#          'decisions': 1,
#          'personnel': 1,
#          'scheme': 1,
#          'focus': 1,
#          'states': 15,
#          '250': 1,
#          'bills': 5,
#          'restrict': 2,
#          'voting': 6,
#          'rights': 6,
#          '70': 9,
#          'transgender': 3,
#          'two': 21,
#          'months': 11,
#          '2021': 1,
#          'boeing': 4,
#          'factory': 3,
#          'disguised': 1,
#          'fake': 1,
#          'neighborhood': 4,
#          'wwii': 2,
#          'ground': 2,
#          'burlap': 1,
#          'canvas': 2,
#          'chicken': 4,
#          'wire': 1,
#          'lawns': 1,
#          'trees': 4,
#          'spun': 1,
#          'glass': 2,
#          'feathers': 1,
#          'buildings': 2,
#          '4ft': 1,
#          'tall': 1,
#          '6pm': 1,
#          'sunsets': 2,
#          'coming': 7,
#          'soon': 2,
#          'neon': 1,
#          'snow': 6,
#          'partner': 1,
#          'using': 14,
#          'miscarriages': 1,
#          'control': 5,
#          'police': 39,
#          'bellevue': 3,
#          'law': 10,
#          'enforcement': 1,
#          'immediately': 4,
#          'stop': 12,
#          'arresting': 2,
#          'people': 34,
#          'drug': 4,
#          'possession': 5,
#          'rescued': 4,
#          'thief': 2,
#          'stole': 1,
#          '15k': 1,
#          'stuff': 5,
#          'storage': 2,
#          'unit': 2,
#          'secured': 1,
#          'garage': 3,
#          'apartment': 11,
#          'complex': 2,
#          'addition': 4,
#          'wealthy': 3,
#          'switzerland': 4,
#          'pool': 6,
#          'boats': 6,
#          'poor': 8,
#          'wisconsin': 2,
#          'picnic': 1,
#          'table': 4,
#          'us': 42,
#          'poors': 1,
#          'times': 25,
#          'hard': 9,
#          'news': 17,
#          'dick': 4,
#          'latvia': 1,
#          'floating': 4,
#          'hottubs': 1,
#          'hottub': 1,
#          'union': 4,
#          'greenberg': 1,
#          'chicago': 5,
#          'bears': 4,
#          'really': 15,
#          'persistent': 1,
#          'reciprocating': 1,
#          'interest': 1,
#          'trading': 1,
#          'quarterback': 4,
#          'kraken': 6,
#          'joining': 4,
#          'current': 5,
#          'sports': 4,
#          'scene': 4,
#          'ctb': 1,
#          'gruden': 1,
#          'sea': 5,
#          'drafting': 1,
#          'russ': 2,
#          '2012': 4,
#          'like': 43,
#          'pick': 10,
#          'm': 46,
#          'jealous': 1,
#          'wish': 3,
#          'could': 14,
#          'coach': 9,
#          'kid': 4,
#          'adam': 3,
#          'schefter': 6,
#          'twitter': 12,
#          'told': 20,
#          'wants': 6,
#          'play': 17,
#          'trade': 9,
#          'considered': 2,
#          'teams': 22,
#          'would': 26,
#          'go': 28,
#          'cowboys': 2,
#          'saints': 6,
#          'raiders': 4,
#          'demanded': 1,
#          'agent': 4,
#          'mark': 7,
#          'rodgers': 3,
#          'espn': 10,
#          'kyed': 1,
#          'going': 20,
#          'issues': 2,
#          'nine': 1,
#          'years': 52,
#          'career': 10,
#          'makes': 10,
#          'brady': 4,
#          'belichick': 2,
#          '20': 20,
#          'year': 55,
#          'marriage': 1,
#          'much': 15,
#          'remarkable': 1,
#          'urgent': 1,
#          'carry': 3,
#          'ban': 18,
#          'likely': 6,
#          'voted': 4,
#          'senate': 2,
#          'tomorrow': 2,
#          'contact': 3,
#          'senators': 1,
#          'clear': 6,
#          'morning': 27,
#          'pentax645n': 1,
#          '75mm': 1,
#          'f': 9,
#          '2': 44,
#          '8': 11,
#          'portra400': 1,
#          'nightengale': 1,
#          'mariners': 38,
#          'prospect': 1,
#          'jarred': 1,
#          'kelenic': 1,
#          'says': 14,
#          'team': 59,
#          'punishing': 2,
#          'refusing': 2,
#          'fallout': 4,
#          'set': 7,
#          'pacific': 7,
#          'northwest': 3,
#          'offer': 4,
#          'terrain': 1,
#          'variety': 1,
#          'series': 18,
#          'overflowing': 1,
#          'radioactive': 1,
#          'desert': 1,
#          'amazon': 16,
#          'terrible': 1,
#          'disgusting': 3,
#          'overrated': 1,
#          'way': 13,
#          'large': 4,
#          'company': 8,
#          'waste': 2,
#          'produces': 1,
#          'one': 61,
#          'biggest': 3,
#          'problems': 1,
#          'proud': 6,
#          'boys': 6,
#          'leader': 6,
#          'threatened': 3,
#          'war': 8,
#          'ahead': 2,
#          'capitol': 7,
#          'riot': 2,
#          'arrested': 11,
#          'charge': 2,
#          'solar': 3,
#          'powered': 1,
#          'watch': 6,
#          'sun': 5,
#          'therapy': 5,
#          'lamp': 1,
#          'live': 17,
#          'post': 52,
#          'ever': 26,
#          'reddit': 22,
#          'wall': 6,
#          'update': 11,
#          'oh': 3,
#          'gosh': 1,
#          'guys': 6,
#          'scooter': 1,
#          'found': 43,
#          'special': 8,
#          'shout': 2,
#          'u': 19,
#          'nihilonym': 1,
#          'connecting': 1,
#          'op': 2,
#          'app': 1,
#          'lemon': 1,
#          'home': 41,
#          'belongs': 1,
#          'nearly': 6,
#          'damaged': 2,
#          'thought': 10,
#          'either': 2,
#          'almost': 5,
#          'miles': 6,
#          'thanks': 4,
#          'r': 60,
#          'lockdown': 1,
#          'kickstarted': 1,
#          'love': 26,
#          'reading': 9,
#          'may': 15,
#          'created': 3,
#          'nice': 4,
#          'corner': 4,
#          'best': 9,
#          'hobbies': 1,
#          'collecting': 1,
#          'books': 1,
#          'better': 3,
#          'mostly': 2,
#          'empty': 3,
#          'used': 6,
#          'three': 6,
#          'cheers': 3,
#          'bokhee': 1,
#          'blessed': 2,
#          'person': 8,
#          'grace': 1,
#          'mercy': 1,
#          'death': 6,
#          'living': 17,
#          'life': 19,
#          'drama': 4,
#          'since': 25,
#          '2005': 1,
#          'snapped': 3,
#          'shot': 16,
#          'public': 17,
#          'library': 6,
#          'day': 33,
#          'curtis': 1,
#          'rogers': 2,
#          'greg': 2,
#          'olsen': 1,
#          'colin': 3,
#          'cowherd': 1,
#          'today': 51,
#          'liked': 1,
#          'buyer': 2,
#          'remorse': 2,
#          'buffalo': 3,
#          'know': 14,
#          'paid': 9,
#          '7m': 1,
#          'barely': 2,
#          'production': 1,
#          '1951': 2,
#          'atrium': 2,
#          'full': 16,
#          'natural': 2,
#          'light': 9,
#          'refurbished': 2,
#          'renovated': 3,
#          'mid': 4,
#          'century': 5,
#          'modern': 2,
#          'residence': 3,
#          'asian': 3,
#          'inspired': 5,
#          'aesthetics': 1,
#          'seward': 2,
#          'park': 18,
#          'originally': 2,
#          'designed': 4,
#          'architect': 1,
#          'paul': 4,
#          'kirk': 1,
#          'finished': 7,
#          '1953': 1,
#          'olson': 1,
#          'kundig': 1,
#          '2015': 12,
#          'every': 38,
#          'mlb': 4,
#          'moved': 12,
#          'least': 10,
#          'populated': 2,
#          'town': 1,
#          'respective': 1,
#          'state': 33,
#          'well': 13,
#          'research': 5,
#          'renamed': 1,
#          'accordingly': 1,
#          'turns': 6,
#          'flying': 12,
#          'phoenix': 7,
#          'takes': 6,
#          'directly': 4,
#          'grand': 2,
#          'canyon': 2,
#          '4032x2268': 1,
#          'photograph': 3,
#          'brave': 2,
#          'ironworker': 1,
#          '1980': 5,
#          'man': 39,
#          'enjoying': 1,
#          'beer': 2,
#          'local': 12,
#          'bar': 5,
#          'approximately': 1,
#          '1950': 1,
#          'bookstore': 2,
#          'closed': 3,
#          'dad': 11,
#          'airline': 2,
#          'pilot': 4,
#          '33': 2,
#          'depart': 1,
#          'san': 12,
#          'diego': 7,
#          'hours': 19,
#          'final': 9,
#          'flight': 12,
#          'boarded': 1,
#          'plane': 17,
#          'headed': 1,
#          'surprise': 1,
#          'join': 9,
#          'last': 48,
#          'leg': 1,
#          'journey': 2,
#          'retirement': 2,
#          'federal': 11,
#          'cops': 9,
#          'already': 3,
#          'mayor': 42,
#          'pissed': 2,
#          'hockey': 2,
#          'came': 7,
#          'together': 7,
#          'newest': 1,
#          'nhl': 13,
#          'revealed': 4,
#          'logos': 3,
#          'anchor': 3,
#          'space': 26,
#          'needle': 24,
#          'report': 8,
#          '1500': 2,
#          'increase': 4,
#          'homeowners': 2,
#          'moving': 8,
#          'area': 15,
#          'compared': 4,
#          'getting': 12,
#          'ready': 3,
#          'expansion': 8,
#          'draft': 12,
#          'named': 4,
#          'announces': 3,
#          'welcome': 7,
#          '32nd': 1,
#          'franchise': 8,
#          'comes': 3,
#          'entire': 6,
#          'government': 3,
#          'body': 4,
#          'infiltrated': 1,
#          'sickos': 1,
#          'portland': 14,
#          'whatever': 1,
#          'shithole': 1,
#          'edith': 1,
#          'macefield': 1,
#          'house': 21,
#          'ballard': 1,
#          '1960': 2,
#          '2019': 14,
#          'movie': 5,
#          'mother': 4,
#          'chop': 1,
#          'shooting': 6,
#          'victim': 4,
#          'files': 2,
#          'wrongful': 1,
#          'claim': 2,
#          'crowd': 13,
#          'weapons': 3,
#          'violated': 2,
#          'consent': 1,
#          'decree': 1,
#          'doj': 1,
#          'lost': 13,
#          'sauce': 2,
#          'authoritarian': 1,
#          'test': 5,
#          'run': 11,
#          'protesters': 13,
#          'peacefully': 2,
#          'looting': 2,
#          'never': 12,
#          'gets': 19,
#          'old': 38,
#          '14': 6,
#          'd': 34,
#          'say': 7,
#          'went': 13,
#          'pretty': 9,
#          'fill': 3,
#          'picking': 2,
#          'black': 8,
#          'chief': 7,
#          'explains': 2,
#          'councilwoman': 4,
#          'fire': 6,
#          'white': 13,
#          'officers': 2,
#          'british': 1,
#          'ambassador': 1,
#          'launched': 1,
#          'official': 7,
#          'complaint': 1,
#          'arrest': 6,
#          'independent': 3,
#          'journalist': 4,
#          'covering': 4,
#          'protests': 11,
#          'andrew': 2,
#          'buncombe': 1,
#          'shackled': 1,
#          'assaulted': 3,
#          'detained': 1,
#          'six': 5,
#          'accused': 7,
#          'failing': 2,
#          'disperse': 1,
#          're': 39,
#          'putting': 5,
#          'lawlessness': 1,
#          'antifa': 9,
#          'women': 13,
#          'charged': 11,
#          'terrorism': 1,
#          'fox': 6,
#          'publishes': 2,
#          'digitally': 3,
#          'altered': 3,
#          'misleading': 2,
#          'images': 5,
#          'demonstrations': 2,
#          'removes': 1,
#          'image': 4,
#          'doctored': 1,
#          'photos': 5,
#          'protest': 13,
#          'zone': 8,
#          'need': 23,
#          'flood': 1,
#          'internet': 9,
#          'videos': 4,
#          'peaceful': 4,
#          'reality': 1,
#          'coronavirus': 2,
#          'survivor': 9,
#          '1': 71,
#          'million': 15,
#          '181': 2,
#          'page': 5,
#          'hospital': 7,
#          'bill': 16,
#          'italian': 2,
#          'imagine': 3,
#          'country': 11,
#          'healthcare': 2,
#          'wonder': 4,
#          'someone': 19,
#          'recover': 2,
#          'silent': 3,
#          'march': 13,
#          'move': 6,
#          'silence': 1,
#          'aclu': 1,
#          'showed': 2,
#          'judge': 16,
#          'footage': 7,
#          'violence': 7,
#          'richard': 6,
#          'jones': 10,
#          'issued': 1,
#          'temp': 1,
#          'restraining': 3,
#          'order': 12,
#          'preventing': 2,
#          'department': 5,
#          'pepper': 7,
#          'spray': 2,
#          'tear': 4,
#          'gas': 6,
#          'chemical': 2,
#          'force': 4,
#          'bars': 4,
#          'nonviolent': 1,
#          'hyundai': 1,
#          'veloster': 1,
#          'n': 5,
#          'performance': 2,
#          '13': 13,
#          '000': 23,
#          'mile': 3,
#          'review': 3,
#          'mural': 1,
#          'pine': 2,
#          'st': 29,
#          'part': 11,
#          'ii': 6,
#          'thread': 42,
#          'right': 31,
#          'wing': 1,
#          'media': 3,
#          'militants': 1,
#          'seized': 2,
#          'authorities': 1,
#          'otherwise': 1,
#          'illegal': 6,
#          'trump': 49,
#          'sent': 2,
#          'military': 2,
#          'encampment': 2,
#          'matt': 4,
#          'gaetz': 1,
#          'promoted': 1,
#          'conspiracy': 1,
#          'theory': 1,
#          'describing': 1,
#          'fictitious': 1,
#          'takeover': 2,
#          'virgin': 2,
#          'vs': 13,
#          'chad': 1,
#          'sealand': 1,
#          'chaz': 1,
#          'mistake': 1,
#          'hey': 7,
#          'heard': 5,
#          'tearing': 3,
#          'statues': 3,
#          'lenin': 8,
#          'statue': 15,
#          'next': 16,
#          'threatens': 2,
#          'invade': 2,
#          'tells': 15,
#          'bunker': 5,
#          'brandon': 3,
#          'bostick': 1,
#          'bitter': 1,
#          'sweet': 2,
#          'month': 10,
#          'personally': 3,
#          'diagnosed': 1,
#          'anxiety': 1,
#          'depression': 2,
#          'turned': 8,
#          '31': 4,
#          'graduated': 1,
#          'college': 7,
#          'completed': 1,
#          'dreams': 2,
#          '5years': 1,
#          'nfl': 37,
#          'degree': 6,
#          'god': 3,
#          'story': 8,
#          'mentalhealthmatters': 1,
#          'responds': 3,
#          'criticizes': 1,
#          'handling': 1,
#          'autonomous': 7,
#          'entering': 1,
#          'cap': 1,
#          'hill': 6,
#          'follow': 2,
#          'shooter': 4,
#          'nikolas': 1,
#          'fernandez': 2,
#          'shows': 4,
#          'pedestrians': 1,
#          'began': 1,
#          'chasing': 2,
#          'car': 11,
#          'onto': 6,
#          'street': 10,
#          'leading': 4,
#          'towards': 4,
#          'protestors': 1,
#          'count': 2,
#          'assault': 2,
#          'gonna': 1,
#          'send': 2,
#          'army': 6,
#          'take': 10,
#          'yawn': 1,
#          'president': 10,
#          'governor': 3,
#          'rejected': 1,
#          'mockery': 1,
#          'radical': 2,
#          'left': 15,
#          'jayinslee': 1,
#          'taunted': 1,
#          'played': 10,
#          'level': 2,
#          'seen': 19,
#          'ugly': 1,
#          'anarchists': 2,
#          'must': 9,
#          'stooped': 1,
#          'fast': 3,
#          'educational': 1,
#          'night': 23,
#          'without': 9,
#          'militarized': 1,
#          'riotous': 1,
#          'looters': 1,
#          'watching': 5,
#          'documentaries': 1,
#          'fuck': 7,
#          'spd': 2,
#          'photo': 21,
#          'credit': 7,
#          'close': 1,
#          'friend': 9,
#          'try': 7,
#          'start': 13,
#          'commune': 1,
#          'within': 5,
#          'days': 24,
#          'taken': 15,
#          'heavily': 1,
#          'armed': 4,
#          'warlord': 1,
#          'crew': 3,
#          'mad': 3,
#          'max': 1,
#          'dystopia': 1,
#          'boot': 1,
#          'metallica': 1,
#          'moshpit': 1,
#          '9': 15,
#          '17': 5,
#          'ran': 7,
#          'manager': 1,
#          'cup': 9,
#          'won': 16,
#          'see': 16,
#          'win': 21,
#          'organizers': 2,
#          '18': 6,
#          'lesbian': 2,
#          'anarchist': 2,
#          'abolish': 1,
#          'whiteness': 1,
#          'capitalism': 1,
#          'civilization': 2,
#          'begged': 1,
#          'vegan': 1,
#          'meats': 1,
#          'soy': 1,
#          'homeless': 11,
#          'invited': 2,
#          'took': 18,
#          'hmmm': 1,
#          'communism': 1,
#          'working': 9,
#          'newly': 2,
#          'established': 1,
#          'residents': 8,
#          'hall': 1,
#          'grandmother': 1,
#          '102': 1,
#          'care': 4,
#          'facility': 2,
#          'couldn': 1,
#          'visit': 5,
#          'nurses': 1,
#          'helped': 6,
#          'zoom': 1,
#          'amazing': 7,
#          'woman': 14,
#          'struck': 2,
#          'flashbang': 1,
#          'saw': 14,
#          'headass': 1,
#          'call': 5,
#          'folks': 4,
#          'larpers': 1,
#          'lives': 10,
#          'matter': 4,
#          'sues': 3,
#          'violent': 3,
#          'tactics': 1,
#          'o7': 1,
#          'map': 6,
#          'battlespace': 1,
#          'fsa': 1,
#          'controls': 2,
#          'several': 2,
#          'blocks': 2,
#          'pushing': 1,
#          'authority': 1,
#          'agents': 3,
#          'saa': 1,
#          'unclear': 2,
#          'erdogan': 1,
#          'react': 2,
#          'pd': 6,
#          'hit': 7,
#          '21': 9,
#          'female': 6,
#          'chest': 4,
#          'stun': 2,
#          'grenade': 2,
#          'keeps': 1,
#          'blazing': 1,
#          'hot': 6,
#          'handing': 1,
#          'cannabis': 3,
#          'online': 3,
#          'system': 5,
#          'made': 36,
#          'based': 9,
#          'democracy': 1,
#          'hacked': 1,
#          'alter': 2,
#          'detection': 1,
#          'according': 8,
#          'mit': 1,
#          'university': 9,
#          'michigan': 2,
#          'brothers': 1,
#          'cop': 7,
#          'info': 4,
#          'inside': 13,
#          'camera': 7,
#          'crushed': 2,
#          'formatted': 2,
#          'sd': 2,
#          'card': 9,
#          'dead': 7,
#          'drive': 9,
#          'w': 6,
#          'engaging': 2,
#          'misconduct': 4,
#          'help': 13,
#          'get': 44,
#          'volunteer': 5,
#          'medics': 1,
#          'rushed': 2,
#          'aid': 2,
#          'carried': 1,
#          'away': 19,
#          'unresponsive': 1,
#          'pulse': 2,
#          'revived': 1,
#          'remains': 1,
#          'critical': 2,
#          'condition': 3,
#          'half': 4,
#          'canadian': 5,
#          'population': 1,
#          'south': 9,
#          'shoot': 1,
#          'unknown': 2,
#          'canister': 1,
#          'near': 15,
#          'banned': 6,
#          '30': 18,
#          'hour': 13,
#          'ago': 24,
#          '11th': 2,
#          'inching': 1,
#          'forward': 4,
#          'streets': 5,
#          'didn': 11,
#          'claimed': 2,
#          'threw': 2,
#          'bottle': 1,
#          'proceeded': 1,
#          'use': 11,
#          'flash': 1,
#          'bangs': 1,
#          'cs': 3,
#          'angles': 1,
#          'community': 5,
#          'rallies': 1,
#          'cleanup': 1,
#          'downtown': 27,
#          'fictoria': 1,
#          'bn': 1,
#          'travelers': 1,
#          'trash': 6,
#          'violating': 1,
#          'stay': 5,
#          'covid': 1,
#          'orders': 3,
#          'vet': 1,
#          'excited': 3,
#          'wheel': 7,
#          'learning': 1,
#          'editing': 1,
#          'fun': 4,
#          'staying': 4,
#          'representing': 1,
#          'mt': 9,
#          'rainier': 13,
#          'usa': 11,
#          'rapoport': 4,
#          'tarvaris': 2,
#          'jackson': 9,
#          'died': 5,
#          'accident': 3,
#          'alabama': 3,
#          'spokesperson': 2,
#          'employer': 2,
#          'tennessee': 2,
#          'tsu': 2,
#          'along': 6,
#          'vikings': 6,
#          'ian': 1,
#          'kevin': 11,
#          'garnett': 1,
#          'recently': 16,
#          'deep': 4,
#          'affinity': 1,
#          'able': 2,
#          'buy': 5,
#          'supersonics': 13,
#          'reactivate': 1,
#          'huge': 4,
#          'league': 22,
#          'mcmanus': 1,
#          'eagles': 3,
#          'point': 7,
#          'underdogs': 1,
#          'holds': 3,
#          'philly': 3,
#          'underdog': 3,
#          ...})

# %% [markdown]
# ## Word Shift Graphs — Proportion Shift

# %% [markdown]
# Nice! Now that we have our two dictionaries, we can use `Shifterator`.

# %% [markdown]
# ## Install and Import Shifterator

# %%
# !pip install shifterator

# %%
import shifterator as sh

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# > The easiest word shift graph that we can construct is a proportion shift. If 𝑝(1)𝑖 is the relative frequency of word 𝑖 in the first text, and 𝑝(2)𝑖 is its relative frequency in the second text, then the proportion shift calculates their difference:
#
# > 𝛿𝑝𝑖=𝑝(2)𝑖−𝑝(1)𝑖.
# > If the difference is positive (𝛿𝑝𝑖>0), then the word is relatively more common in the second text. If it is negative (𝛿𝑝𝑖<0), then it is relatively more common in the first text. We can rank words by this difference and plot them as a word shift graph.

# %% [markdown]
# ## 🛑  Pause!
# Before you run this cell, take a few minutes and make predictions about what words you think are going to be the most relatively frequent in Seattle Reddit posts and Portland Reddit posts. Jot down a few thoughts.

# %%
# Predictions and thoughts

# %% [markdown]
# ## 🚦 Go!

# %%
proportion_shift = sh.ProportionShift(type2freq_1 = #Dictionary 1,
                                        type2freq_2= #Dictionary 2)

proportion_shift.get_shift_graph(system_names = ['Seattle', 'Portland'],  width=15, height=15, cumulative_inset=False,  top_n = 50)

# %% [markdown]
# Check to see where certain words show up in the Seattle Reddit data:

# %%
word_filter = seattle_df['title'].str.contains('Insert a word here!!', case=False)
seattle_df[#Your code here]

# %% [markdown]
# Check to see where certain words show up in the PDX Reddit data:

# %%
word_filter = pdx_df['title'].str.contains('Insert a word here!!', case=False)
pdx_df[#Your code here]

# %% [markdown]
# ### Top 50 Words with Highest Relevant Frequency for Portland

# %% [markdown]
# To sort the words by score, we can use `.get_shift_scores() with a Counter. To select just the top 50, we need to use list slicing.

# %%
Counter(proportion_shift.get_shift_scores()).most_common()#Your code here -- slice the top 50

# %% [markdown]
# ### Top 50 Words with Highest Relevant Frequency for Seattle

# %% [markdown]
# To sort the words by score, we can use `.get_shift_scores() with a Counter. To select just the bottom 50, we need to use list slicing.

# %%
Counter(proportion_shift.get_shift_scores()).most_common()#Your code here -- slice the bottom 50

# %% [markdown]
# ## 🛑  Interpretation & Analysis

# %% [markdown]
# What kind of claims could you make about the Seattle vs. Reddit posts based on the word shift graph of relative word frequency? Try to formulate it in one or two sentences.

# %%
# Your claims here

# %% [markdown]
# ## Save a Word Shift Graph

# %% [markdown]
# To save a word shift graph, we simply need to add a `filename`.

# %%
proportion_shift = sh.ProportionShift(type2freq_1 = seattle_counts,
                                        type2freq_2= pdx_counts)

proportion_shift.get_shift_graph(system_names = ['Seattle', 'Portland'],  width=15, height=15, cumulative_inset=False,  top_n = 50, filename='SeattlevPDX.png')

# %% [markdown]
# ## Word Shift Graph — Entropy

# %%
entropy_shift = sh.EntropyShift(type2freq_1 = #Dictionary 1,
                                type2freq_2= #Dictionary 2,
                                base=2)

entropy_shift.get_shift_graph(system_names = ['Seattle', 'Portland'],  width=15, height=15, cumulative_inset=False,  top_n = 50)

# %% [markdown]
# ## Word Shift Graph — Sentiment Analysis

# %% [markdown]
# We can also use a sentiment lexicon to see which corpora is more or less positive, and we can see which words contribute to that score. Here we will use the labMT Sentiment Lexicon, where 1 is the least happy and 9 is the most happy.
#
# In the graph below, the `type2freq_2` dictionary will be the "reference" corpora.

# %%
sentiment_shift = sh.WeightedAvgShift(type2freq_1 = #Dictionary 1,
                                type2freq_2= Dictionary 2,
                                type2score_1='labMT_English',
                                stop_lens=[(4,6)]
                                )

sentiment_shift.get_shift_graph(system_names = ['Seattle', 'Portland'],  width=15, height=15, cumulative_inset=False, top_n =50)

# %% [markdown]
# ## Top 50 Most Positive or Negative Words

# %%
Counter(entropy_shift.get_shift_scores()).most_common()#Your code here

# %% [markdown]
# ## 🛑  Interpretation & Analysis

# %% [markdown]
# What kind of claims, if any, could you make about the Seattle vs. Reddit posts based on the word shift graph of sentiment difference? Try to formulate it in one or two sentences.

# %%
# Your claims here

# %% [markdown]
# ## Compare Two Different Cities (Or Two Corpora)

# %%
ls ../reddit-data/
# Out:
# Ask-Men-Reddit-Submissions-1k.csv    LA-Reddit-Submissions-1k.csv
# Ask-Women-Reddit-Submissions-1k.csv  Portland-Reddit-Submissions-1k.csv
# Beijing-Reddit-Submissions-1k.csv    Rogue-One-Reddit-Submissions-1k.csv
# Chicago-Reddit-Submissions-1k.csv    Seattle-Reddit-Submissions-1k.csv
# Dune-Reddit-Submissions-1k.csv

# %%
city1_df = pd.read_csv('../reddit-data/Seattle-Reddit-Submissions-1k.csv', parse_dates=['date'])
city1_posts = city1_df['title'].to_list()

city1_counts = Counter()

for post in city1_posts:
    words = tokenize_words(post)
    city1_counts.update(words)

# %%
city2_df = pd.read_csv('../reddit-data/Portland-Reddit-Submissions-1k.csv', parse_dates=['date'])
city2_posts = city1_df['title'].to_list()

pdx_counts = Counter()

for post in city2_posts:
    words = tokenize_words(post)
    city2_counts.update(words)

# %%
proportion_shift = sh.ProportionShift(type2freq_1 = #Dictionary 1,
                                        type2freq_2= #Dictionary 2)

proportion_shift.get_shift_graph(system_names = ['City1', 'City2'],  width=15, height=15, cumulative_inset=False,  top_n = 50)
