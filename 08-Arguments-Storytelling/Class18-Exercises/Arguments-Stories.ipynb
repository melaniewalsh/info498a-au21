# %% [markdown]
# # How to Make Arguments and Tell Stories with Data

# %% [markdown]
# # Class Read Aloud

# %% [markdown]
# John Miller's "Trucks and Beer": https://www.johnwmillr.com/trucks-and-beer/

# %% [markdown]
# Smitha Milli and David Bamman's "Beyond Canonical Texts": https://aclanthology.org/D16-1218.pdf

# %% [markdown]
# # Figures

# %%
import seaborn as sns
import pandas as pd

# %%
film_df = pd.read_csv('../../data/Pudding/Pudding-Film-Dialogue-Clean.csv')

sns.scatterplot(data=film_df, x='release_year', y='words', hue='gender')
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='words'>

# %% [markdown]
# Here we will manually add axis labels and title, and save the figure without cutting off parts of it.
#
# Come up with label names for the axes, and a title for this plot:

# %%
import matplotlib.pyplot as plt

ax = sns.scatterplot(data=film_df, x='release_year', y='words', hue='gender')

plt.xlabel('X LABEL HERE', fontsize = 15)
plt.ylabel('Y LABEL HERE', fontsize = 15)
plt.title('TITLE HERE', fontsize = 25)

plt.tight_layout()
ax.figure.savefig('My-Figure.png')

# %% [markdown]
# # Claims, Evidence, Examples

# %% [markdown]
# Example:
# > **Claim**: If an artist is more likely to mention beer in their songs, are they more likely to also mention trucks? It turns out that yes, they are.
#
# > **Examples and Evidence**: For example, I had 46 songs by Cole Swindell in my database, and he mentioned beer in 24 of them, arriving at a percentage of 52%.

# %% [markdown]
# **Claim**: Write a claim related to your final project

# %% [markdown]
# **Examples and Evidence**: Write about evidence or examples to back this claim up

# %% [markdown]
# # Methods

# %% [markdown]
# `To do TASK, we use METHOD/TOOL and take X,Y,Z STEPS`

# %% [markdown]
# Example:
# > To explore the content of these reviews computationally [**TASK**], we sampled one story with more than 500 reviews from 500 different canons and ran Latent Dirichlet Allocation (Blei et al., 2003) with 10 topics on the text of the reviews (excluding names as stopwords) [**TAKE THESE STEPS/USE THIS METHOD/TOOL**].

# %% [markdown]
# Now it's your turn! Come up with 2 sentences for your final project write-up that explains your methodology

# %% [markdown]
# **Method Sentence 1**: To do TASK, we use METHOD/TOOL and take X,Y,Z STEPS

# %% [markdown]
# **Method Sentence 2**: To do TASK, we use METHOD/TOOL and take X,Y,Z STEPS
