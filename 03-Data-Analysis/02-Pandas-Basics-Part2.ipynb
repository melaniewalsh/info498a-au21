# %% [markdown]
# # Pandas Basics Part 2 — Workbook

# %% [markdown]
# In this workbook, we're going to explore the basics of the Python library Pandas.
#
# ## Import Pandas
#
# To use the Pandas library, we first need to `import` it.

# %%
import pandas as pd

# %% [markdown]
# ## Change Display Settings

# %% [markdown]
# By default, Pandas will display 60 rows and 20 columns. I often change [Pandas' default display settings](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html) to show more rows or columns.

# %%
pd.options.display.max_rows = 200

# %% [markdown]
# ## Get Data

# %% [markdown]
# To read in a CSV file, we will use the method `pd.read_csv()` and insert the name of our desired file path.

# %%
pd.read_csv('Bellevue_Almshouse_Dataset.csv')
# Out:
#          date_in first_name  last_name        full_name   age gender  \
# 0     1847-04-17       Mary  Gallagher   Mary Gallagher  28.0      f
# 1     1847-04-08       John  Sanin (?)   John Sanin (?)  19.0      m
# 2     1847-04-17    Anthony      Clark    Anthony Clark  60.0      m
# 3     1847-04-08   Lawrence     Feeney  Lawrence Feeney  32.0      m
# 4     1847-04-13      Henry      Joyce      Henry Joyce  21.0      m
# ...          ...        ...        ...              ...   ...    ...
# 9593  1846-05-23     Joseph       Aton      Joseph Aton  69.0      m
# 9594  1847-06-17       Mary      Smith       Mary Smith  47.0      f
# 9595  1847-06-22    Francis      Riley    Francis Riley  29.0      m
# 9596  1847-07-02     Martin       Dunn      Martin Dunn   4.0      m
# 9597  1847-07-08  Elizabeth       Post   Elizabeth Post  32.0      f
#
#               disease      profession                    children  \
# 0     recent emigrant         married         Child Alana 10 days
# 1     recent emigrant         laborer              Catherine 2 mo
# 2     recent emigrant         laborer  Charles Riley afed 10 days
# 3     recent emigrant         laborer                       Child
# 4     recent emigrant             NaN                  Child 1 mo
# ...               ...             ...                         ...
# 9593              NaN       shoemaker                         NaN
# 9594              NaN             NaN                         NaN
# 9595             lame  superintendent                         NaN
# 9596              NaN             NaN                         NaN
# 9597              NaN             NaN                         NaN
#
#                sent_to             sender1           sender2
# 0             Hospital      superintendent       hd. gibbens
# 1                  NaN  george w. anderson  edward witherell
# 2             Hospital  george w. anderson  edward witherell
# 3                  NaN  george w. anderson    james donnelly
# 4                  NaN  george w. anderson  edward witherell
# ...                ...                 ...               ...
# 9593               NaN             [blank]               NaN
# 9594  Hospital Ward 38             [blank]               NaN
# 9595               NaN             [blank]               NaN
# 9596               NaN             [blank]               NaN
# 9597          Hospital             [blank]               NaN
#
# [9598 rows x 12 columns]

# %%
type(pd.read_csv('Bellevue_Almshouse_Dataset.csv'))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# This creates a Pandas [DataFrame object](https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html#dataframe), one of the two main data structures in Pandas. A DataFrame looks and acts a lot like a spreadsheet, but it has special powers and functions that we will discuss below and in the next few lessons.
#
# | Pandas objects | Explanation                         |
# |----------|-------------------------------------|
# | `DataFrame`    | Like a spreadsheet, 2-dimensional    |
# | `Series`      | Like a column, 1-dimensional                     |
#
# We assign the DataFrame to a variable called `bellevue_df`. It is common convention to name DataFrame variables `df`, but we want to be a bit more specific.

# %%
bellevue_df = pd.read_csv('Bellevue_Almshouse_Dataset.csv')

# %% [markdown]
# ## Examine Data

# %%
bellevue_df.head(3)
# Out:
#       date_in first_name  last_name       full_name   age gender  \
# 0  1847-04-17       Mary  Gallagher  Mary Gallagher  28.0      f
# 1  1847-04-08       John  Sanin (?)  John Sanin (?)  19.0      m
# 2  1847-04-17    Anthony      Clark   Anthony Clark  60.0      m
#
#            disease profession                    children   sent_to  \
# 0  recent emigrant    married         Child Alana 10 days  Hospital
# 1  recent emigrant    laborer              Catherine 2 mo       NaN
# 2  recent emigrant    laborer  Charles Riley afed 10 days  Hospital
#
#               sender1           sender2
# 0      superintendent       hd. gibbens
# 1  george w. anderson  edward witherell
# 2  george w. anderson  edward witherell

# %%
bellevue_df.sample(8)
# Out:
#          date_in first_name last_name          full_name   age gender  \
# 7664  1847-12-11       John    Geough        John Geough  24.0      m
# 5274  1847-03-12      Sarah      Carr         Sarah Carr  24.0      f
# 535   1847-05-22      James   English      James English   6.0      m
# 530   1847-05-22      James   English      James English  60.0      m
# 6234  1847-08-04    Bridget     Duffy      Bridget Duffy  22.0      f
# 1884  1847-12-29  Catherine   Farrell  Catherine Farrell  20.0      f
# 5512  1847-04-24       Patk     Joste         Patk Joste  32.0      m
# 2824  1846-04-02       Mary    Madden        Mary Madden  22.0      f
#
#               disease profession children             sent_to  \
# 7664         sickness    laborer      NaN            Hospital
# 5274      destitution    married      NaN   Long Island Farms
# 535   recent emigrant    laborer      NaN  Blackwell's Island
# 530   recent emigrant        NaN      NaN  Blackwell's Island
# 6234         sickness        NaN      NaN            Hospital
# 1884  recent emigrant   spinster      NaN  Blackwell's Island
# 5512         sickness    laborer      NaN            Hospital
# 2824              NaN    married      NaN                 NaN
#
#                           sender1               sender2
# 7664             william w. lyons                   NaN
# 5274           george w. anderson  benjamin t. phillips
# 535              moses g. leonard     peter c. johnston
# 530              moses g. leonard     peter c. johnston
# 6234             william w. lyons                   NaN
# 1884             william w. lyons                   NaN
# 5512           george w. anderson               a. maro
# 2824  commissioners of emigration                 agent

# %% [markdown]
# ## Get an Overview of the Data

# %% [markdown]
# Generate descriptive statistics for the numerical columns in the data

# %%
bellevue_df.describe()
# Out:
#                age
# count  9548.000000
# mean     30.337039
# std      14.179527
# min       0.080000
# 25%      21.000000
# 50%      28.000000
# 75%      39.000000
# max      97.000000

# %% [markdown]
# Generate descriptive statistics for all the columns in the data

# %%
bellevue_df.describe(include='all')
# Out:
#            date_in first_name last_name   full_name          age gender  \
# count         9598       9594      9598        9598  9548.000000   9598
# unique         653        523      3159        7308          NaN      5
# top     1847-05-24       Mary     Kelly  Mary Smith          NaN      m
# freq           113        979       137          21          NaN   4967
# mean           NaN        NaN       NaN         NaN    30.337039    NaN
# std            NaN        NaN       NaN         NaN    14.179527    NaN
# min            NaN        NaN       NaN         NaN     0.080000    NaN
# 25%            NaN        NaN       NaN         NaN    21.000000    NaN
# 50%            NaN        NaN       NaN         NaN    28.000000    NaN
# 75%            NaN        NaN       NaN         NaN    39.000000    NaN
# max            NaN        NaN       NaN         NaN    97.000000    NaN
#
#          disease profession children   sent_to             sender1  \
# count       6509       8579       37      5666                9521
# unique        75        172       36        77                  59
# top     sickness    laborer    Child  Hospital  george w. anderson
# freq        2710       3116        2      3882                3469
# mean         NaN        NaN      NaN       NaN                 NaN
# std          NaN        NaN      NaN       NaN                 NaN
# min          NaN        NaN      NaN       NaN                 NaN
# 25%          NaN        NaN      NaN       NaN                 NaN
# 50%          NaN        NaN      NaN       NaN                 NaN
# 75%          NaN        NaN      NaN       NaN                 NaN
# max          NaN        NaN      NaN       NaN                 NaN
#
#                   sender2
# count                5212
# unique                 80
# top     peter c. johnston
# freq                 1666
# mean                  NaN
# std                   NaN
# min                   NaN
# 25%                   NaN
# 50%                   NaN
# 75%                   NaN
# max                   NaN

# %% [markdown]
# Generate information about all the columns in the data (such as data types)

# %%
bellevue_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9598 entries, 0 to 9597
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date_in     9598 non-null   object
#  1   first_name  9594 non-null   object
#  2   last_name   9598 non-null   object
#  3   full_name   9598 non-null   object
#  4   age         9548 non-null   float64
#  5   gender      9598 non-null   object
#  6   disease     6509 non-null   object
#  7   profession  8579 non-null   object
#  8   children    37 non-null     object
#  9   sent_to     5666 non-null   object
#  10  sender1     9521 non-null   object
#  11  sender2     5212 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 899.9+ KB

# %% [markdown]
# ## Histograms

# %% [markdown]
# Make a histogram of all numerical columns in the DataFrame

# %%
bellevue_df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'age'}>]], dtype=object)

# %% [markdown]
# ## Select Multiple Columns

# %% [markdown]
# Select multiple columns with double square brackets

# %%
bellevue_df[['first_name', 'age']]
# Out:
#      first_name   age
# 0          Mary  28.0
# 1          John  19.0
# 2       Anthony  60.0
# 3      Lawrence  32.0
# 4         Henry  21.0
# ...         ...   ...
# 9593     Joseph  69.0
# 9594       Mary  47.0
# 9595    Francis  29.0
# 9596     Martin   4.0
# 9597  Elizabeth  32.0
#
# [9598 rows x 2 columns]

# %% [markdown]
# Select a column as a DataFrame with double square brackets

# %%
bellevue_df[['age']]
# Out:
#        age
# 0     28.0
# 1     19.0
# 2     60.0
# 3     32.0
# 4     21.0
# ...    ...
# 9593  69.0
# 9594  47.0
# 9595  29.0
# 9596   4.0
# 9597  32.0
#
# [9598 rows x 1 columns]

# %% [markdown]
# ## Index

# %%
bellevue_df.head()
# Out:
#       date_in first_name  last_name        full_name   age gender  \
# 0  1847-04-17       Mary  Gallagher   Mary Gallagher  28.0      f
# 1  1847-04-08       John  Sanin (?)   John Sanin (?)  19.0      m
# 2  1847-04-17    Anthony      Clark    Anthony Clark  60.0      m
# 3  1847-04-08   Lawrence     Feeney  Lawrence Feeney  32.0      m
# 4  1847-04-13      Henry      Joyce      Henry Joyce  21.0      m
#
#            disease profession                    children   sent_to  \
# 0  recent emigrant    married         Child Alana 10 days  Hospital
# 1  recent emigrant    laborer              Catherine 2 mo       NaN
# 2  recent emigrant    laborer  Charles Riley afed 10 days  Hospital
# 3  recent emigrant    laborer                       Child       NaN
# 4  recent emigrant        NaN                  Child 1 mo       NaN
#
#               sender1           sender2
# 0      superintendent       hd. gibbens
# 1  george w. anderson  edward witherell
# 2  george w. anderson  edward witherell
# 3  george w. anderson    james donnelly
# 4  george w. anderson  edward witherell

# %% [markdown]
# You can access data by index number or label

# %%
bellevue_df.loc[3]
# Out:
# date_in               1847-04-08
# first_name              Lawrence
# last_name                 Feeney
# full_name        Lawrence Feeney
# age                         32.0
# gender                         m
# disease          recent emigrant
# profession               laborer
# children                   Child
# sent_to                      NaN
# sender1       george w. anderson
# sender2           james donnelly
# Name: 3, dtype: object

# %%
bellevue_df.loc[0:5]
# Out:
#       date_in first_name  last_name        full_name   age gender  \
# 0  1847-04-17       Mary  Gallagher   Mary Gallagher  28.0      f
# 1  1847-04-08       John  Sanin (?)   John Sanin (?)  19.0      m
# 2  1847-04-17    Anthony      Clark    Anthony Clark  60.0      m
# 3  1847-04-08   Lawrence     Feeney  Lawrence Feeney  32.0      m
# 4  1847-04-13      Henry      Joyce      Henry Joyce  21.0      m
# 5  1847-04-14    Bridget       Hart     Bridget Hart  20.0      f
#
#            disease profession                    children   sent_to  \
# 0  recent emigrant    married         Child Alana 10 days  Hospital
# 1  recent emigrant    laborer              Catherine 2 mo       NaN
# 2  recent emigrant    laborer  Charles Riley afed 10 days  Hospital
# 3  recent emigrant    laborer                       Child       NaN
# 4  recent emigrant        NaN                  Child 1 mo       NaN
# 5  recent emigrant   spinster                       Child    Shanty
#
#               sender1            sender2
# 0      superintendent        hd. gibbens
# 1  george w. anderson   edward witherell
# 2  george w. anderson   edward witherell
# 3  george w. anderson     james donnelly
# 4  george w. anderson   edward witherell
# 5  george w. anderson  benson s. hopkins

# %%
ward_filter = bellevue_df['sent_to'] == 'Hospital Ward 38'
bellevue_df[ward_filter]
# Out:
#          date_in first_name   last_name            full_name   age gender  \
# 249   1847-05-17  Elizabeth      Cauley     Elizabeth Cauley  24.0      f
# 330   1847-03-22      Sarah    Corrigan       Sarah Corrigan  21.0      f
# 367   1847-06-13    Bridget    Reynolds     Bridget Reynolds  20.0      f
# 499   1847-06-09       Rose       Dinns           Rose Dinns  22.0      f
# 698   1847-08-21    Bridget     Redding      Bridget Redding  25.0      f
# 1041  1847-03-13      Betty        Dunn           Betty Dunn  34.0      f
# 1290  1847-02-17  Catherine     Doherty    Catherine Doherty  34.0      f
# 1426  1847-05-31  Catherine       Riley      Catherine Riley  28.0      f
# 1494  1847-06-14      Brigt     Frikee?        Brigt Frikee?  25.0      f
# 1584  1847-10-28      Ellen        Lamb           Ellen Lamb  20.0      f
# 1685  1847-03-09  Catherine     McManus    Catherine McManus  21.0      f
# 1746  1847-05-08      Ellen     O'Brien        Ellen O'Brien  20.0      f
# 1863  1847-06-01    Bridget        Nash         Bridget Nash  30.0      f
# 1960  1847-05-13       Mary   Gallagher       Mary Gallagher  18.0      f
# 2370  1847-02-13      Eliza     Latimer        Eliza Latimer  19.0      f
# 5194  1847-02-22       Mary      Toohey          Mary Toohey  34.0      f
# 5286  1847-03-16       Mary      Mullen          Mary Mullen  27.0      f
# 5309  1847-03-22   Margaret       Welsh       Margaret Welsh  24.0      f
# 5310  1847-03-22  Elizabeth    McDonald   Elizabeth McDonald  26.0      f
# 5321  1847-03-24  Mary Jane     Stevens    Mary Jane Stevens  30.0      f
# 5445  1847-04-15      Alice       Duffy          Alice Duffy  28.0      f
# 5629  1847-05-10       Jane      McCann          Jane McCann  22.0      f
# 5636  1847-05-10      Susan   Patterson      Susan Patterson  20.0      f
# 5777  1847-08-11    Bridget       Grady        Bridget Grady  35.0      f
# 5935  1847-07-15      Ellen    Connolly       Ellen Connolly  25.0      f
# 6003  1847-07-19       Mary       Kelly           Mary Kelly  27.0      f
# 6051  1847-07-22        Ann       Clark            Ann Clark  23.0      f
# 6052  1847-07-22       Mary      Diffen          Mary Diffen  32.0      f
# 6053  1847-07-22   Mary Ann  Williamson  Mary Ann Williamson  50.0      f
# 6102  1847-07-25   Margaret      McCabe      Margaret McCabe  40.0      f
# 6265  1847-08-06  Elizabeth   Wilkinson  Elizabeth Wilkinson  13.0      f
# 7140  1847-10-20    Bridget       Riley        Bridget Riley  18.0      f
# 7209  1847-10-27        Ann      Rourke           Ann Rourke  20.0      f
# 7221  1847-10-28  Catherine   McDermott  Catherine McDermott  28.0      f
# 7280  1847-11-02      Ellen     Sweeney        Ellen Sweeney  20.0      f
# 7297  1847-11-04       Mary       Smith           Mary Smith  30.0      f
# 7312  1847-11-05    Bridget    Campbell     Bridget Campbell  23.0      f
# 7338  1847-11-08    Bridget    Laughlin     Bridget Laughlin  21.0      f
# 7347  1847-11-09  Catherine   Gillespie  Catherine Gillespie  34.0      f
# 7417  1847-11-16      Eliza      Martin         Eliza Martin  30.0      f
# 7470  1847-11-20  Catherine     O'Brien    Catherine O'Brien  29.0      f
# 8009  1847-06-15     Hannah  Keatherson    Hannah Keatherson  14.0      f
# 8100  1847-02-12       Mary     McGrath         Mary McGrath  26.0      f
# 8101  1847-02-18       Jane       Smith           Jane Smith  25.0      f
# 8125  1847-04-19       Mary       Smith           Mary Smith  23.0      f
# 8129  1847-04-22      Ellen      McCalu         Ellen McCalu  24.0      f
# 8134  1847-05-08      Judah      Fallen         Judah Fallen  30.0      f
# 8180  1847-05-15  Catherine       Seele      Catherine Seele  25.0      f
# 8203  1847-05-18       Mary     Andrews         Mary Andrews  26.0      f
# 8285  1847-05-26      Ellen      McCake         Ellen McCake  23.0      f
# 8303  1847-05-27      Sarah    Campbell       Sarah Campbell  22.0      f
# 8364  1847-06-01    Bridget      Keanan       Bridget Keanan  20.0      f
# 8379  1847-06-02      Sarah     Cormick        Sarah Cormick  46.0      f
# 8410  1847-06-04       Mary        Hart            Mary Hart  37.0      f
# 8424  1847-06-05        Ann       Smith            Ann Smith  24.0      f
# 8479  1847-06-11       Mary      McMagh          Mary McMagh  28.0      f
# 8498  1847-06-13       Mary       Henry           Mary Henry  27.0      f
# 8506  1847-06-14       Mary      Keeler          Mary Keeler  44.0      f
# 8541  1847-06-17       Mary       Smith           Mary Smith  23.0      f
# 8581  1847-06-19     Martha  McConnelly    Martha McConnelly  35.0      f
# 8714  1847-06-26       Jane       Davis           Jane Davis  18.0      f
# 9594  1847-06-17       Mary       Smith           Mary Smith  47.0      f
#
#               disease  profession         children           sent_to  \
# 249   recent emigrant     married  Son Walter 4 mo  Hospital Ward 38
# 330   recent emigrant     married              NaN  Hospital Ward 38
# 367          pregnant     married              NaN  Hospital Ward 38
# 499          pregnant     married              NaN  Hospital Ward 38
# 698          pregnant     married              NaN  Hospital Ward 38
# 1041  recent emigrant     married              NaN  Hospital Ward 38
# 1290  recent emigrant       widow              NaN  Hospital Ward 38
# 1426  recent emigrant     married              NaN  Hospital Ward 38
# 1494  recent emigrant     married              NaN  Hospital Ward 38
# 1584  recent emigrant     married              NaN  Hospital Ward 38
# 1685  recent emigrant       widow              NaN  Hospital Ward 38
# 1746         pregnant    spinster              NaN  Hospital Ward 38
# 1863  recent emigrant     married              NaN  Hospital Ward 38
# 1960         pregnant     married              NaN  Hospital Ward 38
# 2370  recent emigrant     married              NaN  Hospital Ward 38
# 5194         pregnant     married              NaN  Hospital Ward 38
# 5286         pregnant     married              NaN  Hospital Ward 38
# 5309         pregnant     married              NaN  Hospital Ward 38
# 5310         pregnant     married              NaN  Hospital Ward 38
# 5321         pregnant    spinster              NaN  Hospital Ward 38
# 5445         pregnant    spinster              NaN  Hospital Ward 38
# 5629         pregnant    spinster              NaN  Hospital Ward 38
# 5636         pregnant    spinster              NaN  Hospital Ward 38
# 5777         pregnant    spinster              NaN  Hospital Ward 38
# 5935         pregnant     married              NaN  Hospital Ward 38
# 6003         sickness     married              NaN  Hospital Ward 38
# 6051         pregnant    spinster              NaN  Hospital Ward 38
# 6052         pregnant       widow              NaN  Hospital Ward 38
# 6053         pregnant       widow              NaN  Hospital Ward 38
# 6102         pregnant    spinster              NaN  Hospital Ward 38
# 6265         pregnant     married              NaN  Hospital Ward 38
# 7140         pregnant    spinster              NaN  Hospital Ward 38
# 7209         pregnant    spinster              NaN  Hospital Ward 38
# 7221         pregnant     married              NaN  Hospital Ward 38
# 7280         pregnant    spinster              NaN  Hospital Ward 38
# 7297         pregnant    spinster              NaN  Hospital Ward 38
# 7312         pregnant    spinster              NaN  Hospital Ward 38
# 7338         pregnant    spinster              NaN  Hospital Ward 38
# 7347         pregnant     married              NaN  Hospital Ward 38
# 7417         pregnant     married              NaN  Hospital Ward 38
# 7470         pregnant     married              NaN  Hospital Ward 38
# 8009         pregnant     married              NaN  Hospital Ward 38
# 8100         pregnant       widow              NaN  Hospital Ward 38
# 8101         pregnant    spinster              NaN  Hospital Ward 38
# 8125         pregnant    spinster              NaN  Hospital Ward 38
# 8129         pregnant  seamstress              NaN  Hospital Ward 38
# 8134         pregnant       widow              NaN  Hospital Ward 38
# 8180         pregnant     married              NaN  Hospital Ward 38
# 8203         pregnant     married              NaN  Hospital Ward 38
# 8285         pregnant    spinster              NaN  Hospital Ward 38
# 8303         pregnant     married              NaN  Hospital Ward 38
# 8364         pregnant     married              NaN  Hospital Ward 38
# 8379      destitution       widow              NaN  Hospital Ward 38
# 8410         pregnant     married              NaN  Hospital Ward 38
# 8424         pregnant     married              NaN  Hospital Ward 38
# 8479         pregnant    spinster              NaN  Hospital Ward 38
# 8498         pregnant     married              NaN  Hospital Ward 38
# 8506         pregnant        cook              NaN  Hospital Ward 38
# 8541         pregnant         NaN              NaN  Hospital Ward 38
# 8581         pregnant    spinster              NaN  Hospital Ward 38
# 8714         pregnant     married              NaN  Hospital Ward 38
# 9594              NaN         NaN              NaN  Hospital Ward 38
#
#                  sender1                      sender2
# 249     moses g. leonard            peter c. johnston
# 330   george w. anderson            peter c. johnston
# 367     moses g. leonard               oscar s. field
# 499     moses g. leonard            peter c. johnston
# 698     william w. lyons                          NaN
# 1041  george w. anderson            peter c. johnston
# 1290  george w. anderson                          NaN
# 1426    moses g. leonard            peter c. johnston
# 1494    moses g. leonard            peter c. johnston
# 1584    william w. lyons                          NaN
# 1685  george w. anderson               james donnelly
# 1746  george w. anderson            peter c. johnston
# 1863    moses g. leonard            peter c. johnston
# 1960  george w. anderson            peter c. johnston
# 2370  george w. anderson                          NaN
# 5194  george w. anderson            peter c. johnston
# 5286  george w. anderson               james donnelly
# 5309  george w. anderson            benson s. hopkins
# 5310  george w. anderson             edward witherell
# 5321  george w. anderson             edward witherell
# 5445  george w. anderson            peter c. johnston
# 5629  george w. anderson            peter c. johnston
# 5636  george w. anderson            peter c. johnston
# 5777    thomas b. tappen                          NaN
# 5935    william w. lyons                          NaN
# 6003    william w. lyons            charles j. sutton
# 6051    william w. lyons                          NaN
# 6052    william w. lyons                          NaN
# 6053    william w. lyons                          NaN
# 6102    william w. lyons                          NaN
# 6265    william w. lyons                          NaN
# 7140    william w. lyons                          NaN
# 7209    william w. lyons                          NaN
# 7221    william w. lyons                          NaN
# 7280    william w. lyons                          NaN
# 7297    william w. lyons                          NaN
# 7312    william w. lyons                          NaN
# 7338    william w. lyons                          NaN
# 7347    william w. lyons                          NaN
# 7417    william w. lyons                          NaN
# 7470    william w. lyons                          NaN
# 8009    moses g. leonard             edward witherell
# 8100    moses g. leonard            benson s. hopkins
# 8101    moses g. leonard            benson s. hopkins
# 8125    moses g. leonard            benson s. hopkins
# 8129    moses g. leonard  commissioners of emigration
# 8134    moses g. leonard            benson s. hopkins
# 8180    moses g. leonard             edward witherell
# 8203    moses g. leonard            peter c. johnston
# 8285    moses g. leonard            benson s. hopkins
# 8303    moses g. leonard             edward witherell
# 8364    moses g. leonard            benson s. hopkins
# 8379    moses g. leonard             edward witherell
# 8410    moses g. leonard             edward witherell
# 8424    moses g. leonard             edward witherell
# 8479    moses g. leonard               oscar s. field
# 8498    moses g. leonard             edward witherell
# 8506    moses g. leonard               oscar s. field
# 8541    moses g. leonard            peter c. johnston
# 8581    moses g. leonard            peter c. johnston
# 8714    moses g. leonard             edward witherell
# 9594             [blank]                          NaN

# %% [markdown]
# You can get the indices for multiple data points like so

# %%
bellevue_df[ward_filter].index
# Out:
# Int64Index([ 249,  330,  367,  499,  698, 1041, 1290, 1426, 1494, 1584, 1685,
#             1746, 1863, 1960, 2370, 5194, 5286, 5309, 5310, 5321, 5445, 5629,
#             5636, 5777, 5935, 6003, 6051, 6052, 6053, 6102, 6265, 7140, 7209,
#             7221, 7280, 7297, 7312, 7338, 7347, 7417, 7470, 8009, 8100, 8101,
#             8125, 8129, 8134, 8180, 8203, 8285, 8303, 8364, 8379, 8410, 8424,
#             8479, 8498, 8506, 8541, 8581, 8714, 9594],
#            dtype='int64')

# %%
bellevue_df = bellevue_df.drop(3)
# Out:
#          date_in first_name  last_name        full_name   age gender  \
# 0     1847-04-17       Mary  Gallagher   Mary Gallagher  28.0      f
# 1     1847-04-08       John  Sanin (?)   John Sanin (?)  19.0      m
# 2     1847-04-17    Anthony      Clark    Anthony Clark  60.0      m
# 3     1847-04-08   Lawrence     Feeney  Lawrence Feeney  32.0      m
# 4     1847-04-13      Henry      Joyce      Henry Joyce  21.0      m
# ...          ...        ...        ...              ...   ...    ...
# 9593  1846-05-23     Joseph       Aton      Joseph Aton  69.0      m
# 9594  1847-06-17       Mary      Smith       Mary Smith  47.0      f
# 9595  1847-06-22    Francis      Riley    Francis Riley  29.0      m
# 9596  1847-07-02     Martin       Dunn      Martin Dunn   4.0      m
# 9597  1847-07-08  Elizabeth       Post   Elizabeth Post  32.0      f
#
#               disease      profession                    children  \
# 0     recent emigrant         married         Child Alana 10 days
# 1     recent emigrant         laborer              Catherine 2 mo
# 2     recent emigrant         laborer  Charles Riley afed 10 days
# 3     recent emigrant         laborer                       Child
# 4     recent emigrant             NaN                  Child 1 mo
# ...               ...             ...                         ...
# 9593              NaN       shoemaker                         NaN
# 9594              NaN             NaN                         NaN
# 9595             lame  superintendent                         NaN
# 9596              NaN             NaN                         NaN
# 9597              NaN             NaN                         NaN
#
#                sent_to             sender1           sender2
# 0             Hospital      superintendent       hd. gibbens
# 1                  NaN  george w. anderson  edward witherell
# 2             Hospital  george w. anderson  edward witherell
# 3                  NaN  george w. anderson    james donnelly
# 4                  NaN  george w. anderson  edward witherell
# ...                ...                 ...               ...
# 9593               NaN             [blank]               NaN
# 9594  Hospital Ward 38             [blank]               NaN
# 9595               NaN             [blank]               NaN
# 9596               NaN             [blank]               NaN
# 9597          Hospital             [blank]               NaN
#
# [9598 rows x 12 columns]

# %%
bellevue_df.drop(3)
# Out:
#          date_in first_name  last_name       full_name   age gender  \
# 0     1847-04-17       Mary  Gallagher  Mary Gallagher  28.0      f
# 1     1847-04-08       John  Sanin (?)  John Sanin (?)  19.0      m
# 2     1847-04-17    Anthony      Clark   Anthony Clark  60.0      m
# 4     1847-04-13      Henry      Joyce     Henry Joyce  21.0      m
# 5     1847-04-14    Bridget       Hart    Bridget Hart  20.0      f
# ...          ...        ...        ...             ...   ...    ...
# 9593  1846-05-23     Joseph       Aton     Joseph Aton  69.0      m
# 9594  1847-06-17       Mary      Smith      Mary Smith  47.0      f
# 9595  1847-06-22    Francis      Riley   Francis Riley  29.0      m
# 9596  1847-07-02     Martin       Dunn     Martin Dunn   4.0      m
# 9597  1847-07-08  Elizabeth       Post  Elizabeth Post  32.0      f
#
#               disease      profession                    children  \
# 0     recent emigrant         married         Child Alana 10 days
# 1     recent emigrant         laborer              Catherine 2 mo
# 2     recent emigrant         laborer  Charles Riley afed 10 days
# 4     recent emigrant             NaN                  Child 1 mo
# 5     recent emigrant        spinster                       Child
# ...               ...             ...                         ...
# 9593              NaN       shoemaker                         NaN
# 9594              NaN             NaN                         NaN
# 9595             lame  superintendent                         NaN
# 9596              NaN             NaN                         NaN
# 9597              NaN             NaN                         NaN
#
#                sent_to             sender1            sender2
# 0             Hospital      superintendent        hd. gibbens
# 1                  NaN  george w. anderson   edward witherell
# 2             Hospital  george w. anderson   edward witherell
# 4                  NaN  george w. anderson   edward witherell
# 5               Shanty  george w. anderson  benson s. hopkins
# ...                ...                 ...                ...
# 9593               NaN             [blank]                NaN
# 9594  Hospital Ward 38             [blank]                NaN
# 9595               NaN             [blank]                NaN
# 9596               NaN             [blank]                NaN
# 9597          Hospital             [blank]                NaN
#
# [9597 rows x 12 columns]

# %%
bellevue_df.drop(bellevue_df[ward_filter].index)
# Out:
#          date_in first_name  last_name        full_name   age gender  \
# 0     1847-04-17       Mary  Gallagher   Mary Gallagher  28.0      f
# 1     1847-04-08       John  Sanin (?)   John Sanin (?)  19.0      m
# 2     1847-04-17    Anthony      Clark    Anthony Clark  60.0      m
# 3     1847-04-08   Lawrence     Feeney  Lawrence Feeney  32.0      m
# 4     1847-04-13      Henry      Joyce      Henry Joyce  21.0      m
# ...          ...        ...        ...              ...   ...    ...
# 9592  1847-04-30        Jas     Bowden       Jas Bowden  40.0      m
# 9593  1846-05-23     Joseph       Aton      Joseph Aton  69.0      m
# 9595  1847-06-22    Francis      Riley    Francis Riley  29.0      m
# 9596  1847-07-02     Martin       Dunn      Martin Dunn   4.0      m
# 9597  1847-07-08  Elizabeth       Post   Elizabeth Post  32.0      f
#
#               disease      profession                    children   sent_to  \
# 0     recent emigrant         married         Child Alana 10 days  Hospital
# 1     recent emigrant         laborer              Catherine 2 mo       NaN
# 2     recent emigrant         laborer  Charles Riley afed 10 days  Hospital
# 3     recent emigrant         laborer                       Child       NaN
# 4     recent emigrant             NaN                  Child 1 mo       NaN
# ...               ...             ...                         ...       ...
# 9592         sickness           mason                         NaN  Hospital
# 9593              NaN       shoemaker                         NaN       NaN
# 9595             lame  superintendent                         NaN       NaN
# 9596              NaN             NaN                         NaN       NaN
# 9597              NaN             NaN                         NaN  Hospital
#
#                  sender1           sender2
# 0         superintendent       hd. gibbens
# 1     george w. anderson  edward witherell
# 2     george w. anderson  edward witherell
# 3     george w. anderson    james donnelly
# 4     george w. anderson  edward witherell
# ...                  ...               ...
# 9592   william a. walker               NaN
# 9593             [blank]               NaN
# 9595             [blank]               NaN
# 9596             [blank]               NaN
# 9597             [blank]               NaN
#
# [9536 rows x 12 columns]

# %% [markdown]
# You can make one of the columns into the index

# %%
bellevue_df.set_index('date_in')
# Out:
#            first_name  last_name        full_name   age gender  \
# date_in
# 1847-04-17       Mary  Gallagher   Mary Gallagher  28.0      f
# 1847-04-08       John  Sanin (?)   John Sanin (?)  19.0      m
# 1847-04-17    Anthony      Clark    Anthony Clark  60.0      m
# 1847-04-08   Lawrence     Feeney  Lawrence Feeney  32.0      m
# 1847-04-13      Henry      Joyce      Henry Joyce  21.0      m
# ...               ...        ...              ...   ...    ...
# 1846-05-23     Joseph       Aton      Joseph Aton  69.0      m
# 1847-06-17       Mary      Smith       Mary Smith  47.0      f
# 1847-06-22    Francis      Riley    Francis Riley  29.0      m
# 1847-07-02     Martin       Dunn      Martin Dunn   4.0      m
# 1847-07-08  Elizabeth       Post   Elizabeth Post  32.0      f
#
#                     disease      profession                    children  \
# date_in
# 1847-04-17  recent emigrant         married         Child Alana 10 days
# 1847-04-08  recent emigrant         laborer              Catherine 2 mo
# 1847-04-17  recent emigrant         laborer  Charles Riley afed 10 days
# 1847-04-08  recent emigrant         laborer                       Child
# 1847-04-13  recent emigrant             NaN                  Child 1 mo
# ...                     ...             ...                         ...
# 1846-05-23              NaN       shoemaker                         NaN
# 1847-06-17              NaN             NaN                         NaN
# 1847-06-22             lame  superintendent                         NaN
# 1847-07-02              NaN             NaN                         NaN
# 1847-07-08              NaN             NaN                         NaN
#
#                      sent_to             sender1           sender2
# date_in
# 1847-04-17          Hospital      superintendent       hd. gibbens
# 1847-04-08               NaN  george w. anderson  edward witherell
# 1847-04-17          Hospital  george w. anderson  edward witherell
# 1847-04-08               NaN  george w. anderson    james donnelly
# 1847-04-13               NaN  george w. anderson  edward witherell
# ...                      ...                 ...               ...
# 1846-05-23               NaN             [blank]               NaN
# 1847-06-17  Hospital Ward 38             [blank]               NaN
# 1847-06-22               NaN             [blank]               NaN
# 1847-07-02               NaN             [blank]               NaN
# 1847-07-08          Hospital             [blank]               NaN
#
# [9598 rows x 11 columns]

# %% [markdown]
# ## Sort Values

# %%
bellevue_df.sort_values(by='date_in')
# Out:
#          date_in first_name last_name        full_name   age gender  \
# 9096  1846-01-01    Charles      Kain     Charles Kain  23.0      m
# 2423  1846-01-02  Alexander     Quinn  Alexander Quinn  50.0      m
# 2422  1846-01-02    Patrick      Shea     Patrick Shea  29.0      m
# 2421  1846-01-02    Rosanna    Morris   Rosanna Morris  18.0      f
# 2420  1846-01-02       John  Maybrick    John Maybrick  28.0      m
# ...          ...        ...       ...              ...   ...    ...
# 7850  1847-12-31      Eliza   Harnana    Eliza Harnana  26.0      f
# 7848  1847-12-31        Ann  McDonald     Ann McDonald  25.0      f
# 7847  1847-12-31    Patrick      Hays     Patrick Hays  36.0      m
# 7856  1847-12-31       Mary    Hurley      Mary Hurley  30.0      f
# 7849  1847-12-31    Rosanna    Rourke   Rosanna Rourke  30.0      f
#
#           disease  profession children                     sent_to  \
# 9096          NaN     laborer      NaN                         NaN
# 2423          NaN   shoemaker      NaN                         NaN
# 2422          NaN     laborer      NaN                         NaN
# 2421          NaN    spinster      NaN                         NaN
# 2420          NaN      tinman      NaN                         NaN
# ...           ...         ...      ...                         ...
# 7850     pregnant     married      NaN  Blackwell's Island Ward 38
# 7848  destitution    spinster      NaN          Blackwell's Island
# 7847  destitution  blacksmith      NaN          Blackwell's Island
# 7856     sickness     married      NaN                    Hospital
# 7849  destitution     married      NaN          Blackwell's Island
#
#                           sender1        sender2
# 9096                       police  robert taylor
# 2423  commissioners of emigration          agent
# 2422  commissioners of emigration          agent
# 2421  commissioners of emigration          agent
# 2420  commissioners of emigration          agent
# ...                           ...            ...
# 7850             william w. lyons            NaN
# 7848             william w. lyons            NaN
# 7847             william w. lyons            NaN
# 7856             william w. lyons            NaN
# 7849             william w. lyons            NaN
#
# [9598 rows x 12 columns]

# %%
bellevue_df['age'].sort_values()
# Out:
# 291     0.08
# 7516    0.08
# 1601    0.16
# 99      0.16
# 2204    0.16
#         ...
# 9006     NaN
# 9042     NaN
# 9045     NaN
# 9059     NaN
# 9085     NaN
# Name: age, Length: 9598, dtype: float64

# %%
bellevue_df['age'].sort_values(ascending=False)
# Out:
# 3956    97.0
# 6940    90.0
# 6816    89.0
# 9359    89.0
# 3919    89.0
#         ...
# 9006     NaN
# 9042     NaN
# 9045     NaN
# 9059     NaN
# 9085     NaN
# Name: age, Length: 9598, dtype: float64

# %% [markdown]
# ## Groupby

# %%
bellevue_df.groupby('profession')['age'].mean()
# Out:
# profession
# (illegible)                    26.166667
# apothecary                     21.000000
# auctioneer                     26.000000
# baker                          29.875000
# barber                         59.000000
# barkeeper                      21.750000
# barker                         39.500000
# basket maker                   53.000000
# blacksmith                     37.266990
# boatman                        31.875000
# boiler maker                   29.333333
# book binder                    45.000000
# book keeper                    20.000000
# book maker                     25.750000
# book pedlar                    23.000000
# book seller                    66.000000
# boot maker                     36.600000
# brass founder                  32.000000
# brass turner                   55.000000
# brewer                         36.666667
# brick layer                    34.250000
# brush maker                    22.000000
# builder                        27.000000
# butcher                        31.909091
# cab driver                     29.000000
# cabinet maker                  39.875000
# cabman                         37.000000
# cabrener                       19.000000
# calico printer                 45.000000
# carpenter                      37.261538
# cartman                        34.666667
# carver                         34.000000
# caulker                        25.000000
# chair maker                    26.000000
# chandler                       44.000000
# clerk                          31.464286
# clery                          36.000000
# cloth printer                  60.000000
# coachman                       39.500000
# cook                           44.000000
# cooper                         38.500000
# copoper                        44.000000
# copper smith                   19.500000
# cotton sampler                 38.000000
# courier                        33.000000
# croper                         55.000000
# dancing master                 31.000000
# drayman                        49.000000
# dugget                         32.000000
# dyer                           38.000000
# engineer                       30.000000
# engraver                       36.000000
# farmer                         29.952381
# fishman                        52.000000
# flag cutter                    35.000000
# flag pavier                    35.000000
# flagger                        35.000000
# food carrier                   44.000000
# gardener                       39.480000
# gas fitter                     22.000000
# gas manufacturer               22.000000
# glass cutter                   33.500000
# glove maker                    49.500000
# glover                         45.000000
# grocer                         41.800000
# groom                          18.000000
# gun maker                      47.000000
# gw anderson per e witherell    35.000000
# hacker                         32.000000
# hackman                        40.750000
# harness maker                  23.111111
# hatter                         35.583333
# hodman                         21.000000
# hostler                        34.916667
# iron moulder                   28.000000
# jeweller                       22.000000
# jobber                         86.000000
# joiner                         18.000000
# laborer                        32.752124
# lawyer                         39.000000
# leather draper                 54.000000
# leather dresser                42.000000
# locksmith                      35.333333
# machinist                      41.200000
# magician                       42.000000
# manow(?)                       31.000000
# manufacturer                   65.000000
# marble cutter                  62.000000
# marble polisher                27.800000
# marble sawyer                  50.000000
# mariner                        57.000000
# marketmab                      70.000000
# married                        29.269804
# mason                          39.878788
# merchant                       24.666667
# miner                          27.333333
# miniature painter              25.000000
# morocco dresser                35.000000
# moulder                        30.000000
# music painter                  33.000000
# musician                       27.000000
# nail maker                     39.500000
# nailer                         29.000000
# oysterman                      23.000000
# painter                        34.846154
# paner                          52.000000
# paper maker                    26.500000
# paper stainer                  39.333333
# paper-carrier                  18.000000
# parrier                        60.000000
# pavier                         38.666667
# peddler                        29.050000
# plasterer                      37.666667
# plumber                        16.000000
# polisher                       50.000000
# porter                         35.666667
# printer                        30.090909
# quarry man                     36.000000
# rectifier                      39.000000
# rigger                         43.500000
# saddler                        46.000000
# sail maker                     51.000000
# sailor                         34.300000
# saw maker                      52.000000
# sawyer                         37.500000
# school teacher                 27.000000
# schoolmaster                   25.000000
# seaman                         53.400000
# seamstress                     28.000000
# servant                        33.444444
# sham                           24.000000
# ship carpenter                 36.750000
# ship sawyer                    30.000000
# shipwright                     43.500000
# shoemaker                      38.579618
# shop keeper                    60.000000
# single                         25.000000
# soap boiler                    59.000000
# soap comber                    48.000000
# soapmaker                      30.000000
# soldier                        29.200000
# spinster                       24.961211
# stage driver                   32.000000
# starch maker                   36.666667
# stevedore                      44.500000
# stone cutter                   37.666667
# stone sawyer                   50.000000
# store keeper                   37.666667
# stove maker                    45.500000
# strap maker                    31.000000
# superintendent                 29.000000
# surveyor                       47.000000
# tailor                         34.465517
# tanner                         31.000000
# tavern keeper                  40.000000
# teacher                        43.400000
# teamster                       35.000000
# tinman                         43.250000
# tinsmith                       30.000000
# truss maker                    38.000000
# turner                         44.000000
# type caster                    24.500000
# umbrella maker                 29.000000
# upholsterer                    24.000000
# varnisher                      40.333333
# waiter                         32.975610
# waterman                       28.000000
# weaver                         45.575758
# wheelwright                    44.000000
# widow                          38.929658
# wood sawyer                    49.000000
# wool manufacturer              47.000000
# Name: age, dtype: float64

# %%
bellevue_df.groupby(['profession', 'gender'])['first_name'].count()
# Out:
# profession                   gender
# (illegible)                  f            1
#                              m            5
# apothecary                   m            1
# auctioneer                   m            1
# baker                        f            2
#                              m           46
# barber                       m            2
# barkeeper                    m            4
# barker                       m            2
# basket maker                 m            1
# blacksmith                   m          104
# boatman                      m            8
# boiler maker                 m            9
# book binder                  m            1
# book keeper                  m            1
# book maker                   m            4
# book pedlar                  m            1
# book seller                  m            1
# boot maker                   m           10
# brass founder                m            3
# brass turner                 m            1
# brewer                       m            3
# brick layer                  m            4
# brush maker                  m            1
# builder                      m            1
# butcher                      m           11
# cab driver                   m            2
# cabinet maker                m            8
# cabman                       m            1
# cabrener                     m            1
# calico printer               m            2
# carpenter                    f            1
#                              m           64
# cartman                      m           15
# carver                       m            2
# caulker                      m            1
# chair maker                  m            2
# chandler                     m            1
# clerk                        m           28
# clery                        m            1
# cloth printer                m            1
# coachman                     m           10
# cook                         f            1
# cooper                       m           24
# copoper                      m            1
# copper smith                 m            2
# cotton sampler               m            1
# courier                      m            3
# croper                       m            1
# dancing master               m            1
# drayman                      m            1
# dugget                       m            1
# dyer                         m            4
# engineer                     m            2
# engraver                     m            2
# farmer                       m           21
# fishman                      m            1
# flag cutter                  m            1
# flag pavier                  m            1
# flagger                      m            1
# food carrier                 m            2
# gardener                     f            1
#                              m           24
# gas fitter                   m            1
# gas manufacturer             m            1
# glass cutter                 m            2
# glove maker                  m            2
# glover                       m            1
# grocer                       m            5
# groom                        m            1
# gun maker                    m            1
# gw anderson per e witherell  m            1
# hacker                       m            1
# hackman                      m            4
# harness maker                m            9
# hatter                       m           12
# hodman                       m            1
# hostler                      m           12
# iron moulder                 m            1
# jeweller                     m            1
# jobber                       m            1
# joiner                       m            1
# laborer                      f           27
#                              m         3089
# lawyer                       m            2
# leather draper               m            1
# leather dresser              m            1
# locksmith                    m            3
# machinist                    m            5
# magician                     m            1
# manow(?)                     m            1
# manufacturer                 m            1
# marble cutter                m            1
# marble polisher              m            5
# marble sawyer                m            1
# mariner                      m            1
# marketmab                    m            1
# married                      f         1566
#                              h            1
#                              m           19
# mason                        m           98
# merchant                     m            3
# miner                        m            3
# miniature painter            m            1
# morocco dresser              m            2
# moulder                      m            1
# music painter                m            1
# musician                     m            1
# nail maker                   m            6
# nailer                       m            8
# oysterman                    m            1
# painter                      m           26
# paner                        m            1
# paper maker                  m            2
# paper stainer                m            3
# paper-carrier                m            1
# parrier                      m            1
# pavier                       m            3
# peddler                      f            1
#                              m           19
# plasterer                    m            6
# plumber                      m            1
# polisher                     m            1
# porter                       m            6
# printer                      m           11
# quarry man                   m            2
# rectifier                    m            1
# rigger                       m            2
# saddler                      m            3
# sail maker                   m            2
# sailor                       m           10
# saw maker                    m            1
# sawyer                       m            2
# school teacher               m            1
# schoolmaster                 m            1
# seaman                       m            5
# seamstress                   f            3
# servant                      f            1
#                              m            8
# sham                         f            1
# ship carpenter               m            4
# ship sawyer                  m            1
# shipwright                   m            2
# shoemaker                    m          158
# shop keeper                  m            1
# single                       f            2
# soap boiler                  m            1
# soap comber                  m            1
# soapmaker                    m            1
# soldier                      m            5
# spinster                     f         1508
#                              m           14
# stage driver                 m            1
# starch maker                 m            3
# stevedore                    m            2
# stone cutter                 m           27
# stone sawyer                 m            1
# store keeper                 m            3
# stove maker                  m            2
# strap maker                  m            1
# superintendent               m            1
# surveyor                     m            1
# tailor                       f            1
#                              m          115
# tanner                       m            2
# tavern keeper                m            1
# teacher                      m           10
# teamster                     m            1
# tinman                       m            4
# tinsmith                     m           10
# truss maker                  m            1
# turner                       m            4
# type caster                  m            2
# umbrella maker               m            6
# upholsterer                  m            1
# varnisher                    m            3
# waiter                       f            2
#                              m           39
# waterman                     m            1
# weaver                       f            1
#                              m           65
# wheelwright                  m           14
# widow                        f         1043
#                              g            1
#                              m            9
# wood sawyer                  m            1
# wool manufacturer            m            1
# Name: first_name, dtype: int64

# %% [markdown]
# ## Make Plots

# %%
bellevue_df['gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
bellevue_df['profession'].value_counts()[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
bellevue_df['profession'].value_counts()[:10].plot(kind='bar', color='purple')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Make a Copy

# %%
gender_filter = bellevue_df['gender'] == 'f'

# %%
bellevue_women = bellevue_df[gender_filter].copy()

# %%
bellevue_women
# Out:
#          date_in first_name  last_name         full_name   age gender  \
# 0     1847-04-17       Mary  Gallagher    Mary Gallagher  28.0      f
# 5     1847-04-14    Bridget       Hart      Bridget Hart  20.0      f
# 6     1847-04-14       Mary      Green        Mary Green  40.0      f
# 9     1847-04-10   Margaret    Farrell  Margaret Farrell  30.0      f
# 10    1847-04-10    Bridget        Day       Bridget Day  30.0      f
# ...          ...        ...        ...               ...   ...    ...
# 9587  1847-05-11       Mary     Gannon       Mary Gannon  25.0      f
# 9588  1846-08-14        Ann     Murray        Ann Murray  25.0      f
# 9589  1847-04-28    Bridget       Ryan      Bridget Ryan  28.0      f
# 9594  1847-06-17       Mary      Smith        Mary Smith  47.0      f
# 9597  1847-07-08  Elizabeth       Post    Elizabeth Post  32.0      f
#
#               disease profession             children           sent_to  \
# 0     recent emigrant    married  Child Alana 10 days          Hospital
# 5     recent emigrant   spinster                Child            Shanty
# 6     recent emigrant   spinster   And child 2 months            Shanty
# 9     recent emigrant      widow                  NaN               NaN
# 10    recent emigrant    married                  NaN               NaN
# ...               ...        ...                  ...               ...
# 9587         sickness   spinster                  NaN          Hospital
# 9588              NaN        NaN                  NaN               NaN
# 9589      destitution   spinster                  NaN          Hospital
# 9594              NaN        NaN                  NaN  Hospital Ward 38
# 9597              NaN        NaN                  NaN          Hospital
#
#                  sender1            sender2
# 0         superintendent        hd. gibbens
# 5     george w. anderson  benson s. hopkins
# 6     george w. anderson  benson s. hopkins
# 9                    NaN                NaN
# 10                   NaN                NaN
# ...                  ...                ...
# 9587   william a. walker                NaN
# 9588               widow                NaN
# 9589   william a. walker                NaN
# 9594             [blank]                NaN
# 9597             [blank]                NaN
#
# [4626 rows x 12 columns]

# %% [markdown]
# ## Save a Plot

# %%
top_professions = bellevue_df['profession'].value_counts()[:10]

# %%
top_professions.plot(kind='bar', color='purple', title='Bellevue Almshouse Professions',
                     legend=True, label='professions')
# Out:
# <AxesSubplot:title={'center':'Bellevue Almshouse Professions'}>

# %%
ax = top_professions.plot(kind='bar', color='purple', title='Bellevue Almshouse Professions',
                     legend=True, label='professions')

ax.figure.savefig('Bellevue-Almshouse-Chart.png')
