# %% [markdown]
# # Pandas Basics Part 3 — Workbook

# %% [markdown]
# In this workbook, we're going to explore the basics of the Python library Pandas.
#
# ## Import Pandas
#
# To use the Pandas library, we first need to `import` it.

# %%
import pandas as pd

# %% [markdown]
# ## Change Display Settings

# %% [markdown]
# By default, Pandas will display 60 rows and 20 columns. I often change [Pandas' default display settings](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html) to show more rows or columns.

# %%
pd.options.display.max_rows = 200

# %% [markdown]
# ## Get Data

# %% [markdown]
# To read in a CSV file, we will use the method `pd.read_csv()` and insert the name of our desired file path.

# %%
pd.read_csv('Bellevue_Almshouse_Dataset.csv')
# Out:
#          date_in first_name  last_name        full_name   age gender  \
# 0     1847-04-17       Mary  Gallagher   Mary Gallagher  28.0      f
# 1     1847-04-08       John  Sanin (?)   John Sanin (?)  19.0      m
# 2     1847-04-17    Anthony      Clark    Anthony Clark  60.0      m
# 3     1847-04-08   Lawrence     Feeney  Lawrence Feeney  32.0      m
# 4     1847-04-13      Henry      Joyce      Henry Joyce  21.0      m
# ...          ...        ...        ...              ...   ...    ...
# 9593  1846-05-23     Joseph       Aton      Joseph Aton  69.0      m
# 9594  1847-06-17       Mary      Smith       Mary Smith  47.0      f
# 9595  1847-06-22    Francis      Riley    Francis Riley  29.0      m
# 9596  1847-07-02     Martin       Dunn      Martin Dunn   4.0      m
# 9597  1847-07-08  Elizabeth       Post   Elizabeth Post  32.0      f
#
#               disease      profession                    children  \
# 0     recent emigrant         married         Child Alana 10 days
# 1     recent emigrant         laborer              Catherine 2 mo
# 2     recent emigrant         laborer  Charles Riley afed 10 days
# 3     recent emigrant         laborer                       Child
# 4     recent emigrant             NaN                  Child 1 mo
# ...               ...             ...                         ...
# 9593              NaN       shoemaker                         NaN
# 9594              NaN             NaN                         NaN
# 9595             lame  superintendent                         NaN
# 9596              NaN             NaN                         NaN
# 9597              NaN             NaN                         NaN
#
#                sent_to             sender1           sender2
# 0             Hospital      superintendent       hd. gibbens
# 1                  NaN  george w. anderson  edward witherell
# 2             Hospital  george w. anderson  edward witherell
# 3                  NaN  george w. anderson    james donnelly
# 4                  NaN  george w. anderson  edward witherell
# ...                ...                 ...               ...
# 9593               NaN             [blank]               NaN
# 9594  Hospital Ward 38             [blank]               NaN
# 9595               NaN             [blank]               NaN
# 9596               NaN             [blank]               NaN
# 9597          Hospital             [blank]               NaN
#
# [9598 rows x 12 columns]

# %%
type(pd.read_csv('Bellevue_Almshouse_Dataset.csv'))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# This creates a Pandas [DataFrame object](https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html#dataframe), one of the two main data structures in Pandas. A DataFrame looks and acts a lot like a spreadsheet, but it has special powers and functions that we will discuss below and in the next few lessons.
#
# | Pandas objects | Explanation                         |
# |----------|-------------------------------------|
# | `DataFrame`    | Like a spreadsheet, 2-dimensional    |
# | `Series`      | Like a column, 1-dimensional                     |
#
# We assign the DataFrame to a variable called `bellevue_df`. It is common convention to name DataFrame variables `df`, but we want to be a bit more specific.

# %%
bellevue_df = pd.read_csv('Bellevue_Almshouse_Dataset.csv')

# %% [markdown]
# # Is NA?

# %%
bellevue_df['profession'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 9593    False
# 9594     True
# 9595    False
# 9596     True
# 9597     True
# Name: profession, Length: 9598, dtype: bool

# %%
bellevue_df['profession'].isna().value_counts()
# Out:
# False    8579
# True     1019
# Name: profession, dtype: int64

# %%
bellevue_df['profession'].notna()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 9593     True
# 9594    False
# 9595     True
# 9596    False
# 9597    False
# Name: profession, Length: 9598, dtype: bool

# %% [markdown]
# # Fill NA

# %%
bellevue_df['profession'].fillna('No profession')
# Out:
# 0              married
# 1              laborer
# 2              laborer
# 3              laborer
# 4        No profession
#              ...
# 9593         shoemaker
# 9594     No profession
# 9595    superintendent
# 9596     No profession
# 9597     No profession
# Name: profession, Length: 9598, dtype: object

# %%
bellevue_df['profession'] = bellevue_df['profession'].fillna('No profession')

# %% [markdown]
# ## String Methods

# %%
bellevue_df['profession'].str.title()
# Out:
# 0              Married
# 1              Laborer
# 2              Laborer
# 3              Laborer
# 4        No Profession
#              ...
# 9593         Shoemaker
# 9594     No Profession
# 9595    Superintendent
# 9596     No Profession
# 9597     No Profession
# Name: profession, Length: 9598, dtype: object

# %%
bellevue_df['profession'].str.contains('magic')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9593    False
# 9594    False
# 9595    False
# 9596    False
# 9597    False
# Name: profession, Length: 9598, dtype: bool

# %%
profession_filter = bellevue_df['profession'].str.contains('teach')
bellevue_df[profession_filter]
# Out:
#          date_in first_name last_name         full_name   age gender  \
# 2196  1847-03-12    Michael      Rush      Michael Rush  40.0      m
# 2693  1846-03-11     Thomas     Brady      Thomas Brady  45.0      m
# 3774  1846-07-06      Henry    Dunlap      Henry Dunlap  66.0      m
# 4284  1846-09-03    John B.    Murray    John B. Murray  45.0      m
# 4287  1846-09-03  Alexander    Alcock  Alexander Alcock  46.0      m
# 4612  1846-10-15       John    Dillon       John Dillon  32.0      m
# 5225  1847-03-01  George F.    Robins  George F. Robins  57.0      m
# 5615  1847-05-08    William     Smith     William Smith  27.0      m
# 6254  1847-08-05    Patrick   McGowen   Patrick McGowen  24.0      m
# 8305  1847-05-27    William     Smith     William Smith  29.0      m
# 8653  1847-06-23     Thomas   Gleason    Thomas Gleason  50.0      m
#
#               disease      profession children             sent_to  \
# 2196  recent emigrant         teacher      NaN     Bellevue Garret
# 2693              NaN         teacher      NaN                 NaN
# 3774              NaN         teacher      NaN                 NaN
# 4284              NaN         teacher      NaN                 NaN
# 4287              NaN         teacher      NaN                 NaN
# 4612              NaN         teacher      NaN                 NaN
# 5225      destitution         teacher      NaN     Bellevue Garret
# 5615      destitution  school teacher      NaN    Randall's Island
# 6254         sickness         teacher      NaN            Hospital
# 8305      destitution         teacher      NaN  Blackwell's Island
# 8653         sickness         teacher      NaN            Hospital
#
#                           sender1            sender2  \
# 2196           george w. anderson  peter c. johnston
# 2693  commissioners of emigration              agent
# 3774           george w. anderson                NaN
# 4284           george w. anderson                NaN
# 4287           george w. anderson                NaN
# 4612           george w. anderson                NaN
# 5225           george w. anderson   edward witherell
# 5615           george w. anderson   edward witherell
# 6254             william w. lyons                NaN
# 8305             moses g. leonard   edward witherell
# 8653             moses g. leonard     oscar s. field
#
#                                        senders
# 2196  george w. anderson and peter c. johnston
# 2693     commissioners of emigration and agent
# 3774                                       NaN
# 4284                                       NaN
# 4287                                       NaN
# 4612                                       NaN
# 5225   george w. anderson and edward witherell
# 5615   george w. anderson and edward witherell
# 6254                                       NaN
# 8305     moses g. leonard and edward witherell
# 8653       moses g. leonard and oscar s. field

# %% [markdown]
# ## Rename Column

# %%
bellevue_df.rename(columns={'date_in': 'date_arrived'})
# Out:
#      date_arrived first_name  last_name        full_name   age gender  \
# 0      1847-04-17       Mary  Gallagher   Mary Gallagher  28.0      f
# 1      1847-04-08       John  Sanin (?)   John Sanin (?)  19.0      m
# 2      1847-04-17    Anthony      Clark    Anthony Clark  60.0      m
# 3      1847-04-08   Lawrence     Feeney  Lawrence Feeney  32.0      m
# 4      1847-04-13      Henry      Joyce      Henry Joyce  21.0      m
# ...           ...        ...        ...              ...   ...    ...
# 9593   1846-05-23     Joseph       Aton      Joseph Aton  69.0      m
# 9594   1847-06-17       Mary      Smith       Mary Smith  47.0      f
# 9595   1847-06-22    Francis      Riley    Francis Riley  29.0      m
# 9596   1847-07-02     Martin       Dunn      Martin Dunn   4.0      m
# 9597   1847-07-08  Elizabeth       Post   Elizabeth Post  32.0      f
#
#               disease      profession                    children  \
# 0     recent emigrant         married         Child Alana 10 days
# 1     recent emigrant         laborer              Catherine 2 mo
# 2     recent emigrant         laborer  Charles Riley afed 10 days
# 3     recent emigrant         laborer                       Child
# 4     recent emigrant   No profession                  Child 1 mo
# ...               ...             ...                         ...
# 9593              NaN       shoemaker                         NaN
# 9594              NaN   No profession                         NaN
# 9595             lame  superintendent                         NaN
# 9596              NaN   No profession                         NaN
# 9597              NaN   No profession                         NaN
#
#                sent_to             sender1           sender2
# 0             Hospital      superintendent       hd. gibbens
# 1                  NaN  george w. anderson  edward witherell
# 2             Hospital  george w. anderson  edward witherell
# 3                  NaN  george w. anderson    james donnelly
# 4                  NaN  george w. anderson  edward witherell
# ...                ...                 ...               ...
# 9593               NaN             [blank]               NaN
# 9594  Hospital Ward 38             [blank]               NaN
# 9595               NaN             [blank]               NaN
# 9596               NaN             [blank]               NaN
# 9597          Hospital             [blank]               NaN
#
# [9598 rows x 12 columns]

# %% [markdown]
# ## Add Column

# %%
bellevue_df['senders'] = bellevue_df['sender1'] + ' and ' +  bellevue_df['sender2']

# %%
bellevue_df
# Out:
#          date_in first_name  last_name        full_name   age gender  \
# 0     1847-04-17       Mary  Gallagher   Mary Gallagher  28.0      f
# 1     1847-04-08       John  Sanin (?)   John Sanin (?)  19.0      m
# 2     1847-04-17    Anthony      Clark    Anthony Clark  60.0      m
# 3     1847-04-08   Lawrence     Feeney  Lawrence Feeney  32.0      m
# 4     1847-04-13      Henry      Joyce      Henry Joyce  21.0      m
# ...          ...        ...        ...              ...   ...    ...
# 9593  1846-05-23     Joseph       Aton      Joseph Aton  69.0      m
# 9594  1847-06-17       Mary      Smith       Mary Smith  47.0      f
# 9595  1847-06-22    Francis      Riley    Francis Riley  29.0      m
# 9596  1847-07-02     Martin       Dunn      Martin Dunn   4.0      m
# 9597  1847-07-08  Elizabeth       Post   Elizabeth Post  32.0      f
#
#               disease      profession                    children  \
# 0     recent emigrant         married         Child Alana 10 days
# 1     recent emigrant         laborer              Catherine 2 mo
# 2     recent emigrant         laborer  Charles Riley afed 10 days
# 3     recent emigrant         laborer                       Child
# 4     recent emigrant   No profession                  Child 1 mo
# ...               ...             ...                         ...
# 9593              NaN       shoemaker                         NaN
# 9594              NaN   No profession                         NaN
# 9595             lame  superintendent                         NaN
# 9596              NaN   No profession                         NaN
# 9597              NaN   No profession                         NaN
#
#                sent_to             sender1           sender2  \
# 0             Hospital      superintendent       hd. gibbens
# 1                  NaN  george w. anderson  edward witherell
# 2             Hospital  george w. anderson  edward witherell
# 3                  NaN  george w. anderson    james donnelly
# 4                  NaN  george w. anderson  edward witherell
# ...                ...                 ...               ...
# 9593               NaN             [blank]               NaN
# 9594  Hospital Ward 38             [blank]               NaN
# 9595               NaN             [blank]               NaN
# 9596               NaN             [blank]               NaN
# 9597          Hospital             [blank]               NaN
#
#                                       senders
# 0              superintendent and hd. gibbens
# 1     george w. anderson and edward witherell
# 2     george w. anderson and edward witherell
# 3       george w. anderson and james donnelly
# 4     george w. anderson and edward witherell
# ...                                       ...
# 9593                                      NaN
# 9594                                      NaN
# 9595                                      NaN
# 9596                                      NaN
# 9597                                      NaN
#
# [9598 rows x 13 columns]
